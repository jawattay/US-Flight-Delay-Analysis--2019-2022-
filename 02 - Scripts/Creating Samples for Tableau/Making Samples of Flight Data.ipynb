# %%
#import libraries

import os
import pandas as pd
import numpy as np

# %%
#set path

path = r'D:\Data Analytics\Flight Delay Analysis\01 - Data\Wrangled Data'

# %%
#import data

df2019 = pd.read_csv(os.path.join(path, 'flights2019.csv'), index_col = 0)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15560\2742599022.py:3: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2019 = pd.read_csv(os.path.join(path, 'flights2019.csv'), index_col = 0)

# %%
df2019.shape
# Out:
# (8091684, 60)

# %%
df2019.head()
# Out:
#    Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 0  2019        1      1             4            5  2019-01-04
# 1  2019        1      1             4            5  2019-01-04
# 2  2019        1      1             4            5  2019-01-04
# 3  2019        1      1             4            5  2019-01-04
# 4  2019        1      1             4            5  2019-01-04
#
#   Marketing_Airline_Network_Code IATA_Code_Marketing_Airline  \
# 0                             UA                          UA
# 1                             UA                          UA
# 2                             UA                          UA
# 3                             UA                          UA
# 4                             UA                          UA
#
#   Operating_Airline IATA_Code_Operating_Airline  ... Distance_Group  \
# 0                OO                          OO  ...              1
# 1                OO                          OO  ...              2
# ...

# %%
df2019.tail()
# Out:
#          Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 8091679  2019        4     12            10            2  2019-12-10
# 8091680  2019        4     12            10            2  2019-12-10
# 8091681  2019        4     12            10            2  2019-12-10
# 8091682  2019        4     12            10            2  2019-12-10
# 8091683  2019        4     12            10            2  2019-12-10
#
#         Marketing_Airline_Network_Code IATA_Code_Marketing_Airline  \
# 8091679                             UA                          UA
# 8091680                             UA                          UA
# 8091681                             UA                          UA
# 8091682                             UA                          UA
# 8091683                             UA                          UA
#
#         Operating_Airline IATA_Code_Operating_Airline  ... Distance_Group  \
# ...

# %% [markdown]
# ## Need to combine 5 samples from each combined data set for Tableau analysis.
# ### Starting with 2019 below

# %%
#creating sample of 250,000 records from 2019 data

sample19 = pd.read_csv(os.path.join(path, 'flights2019.csv')).sample(250000, random_state = 11)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15560\4279558183.py:3: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   sample19 = pd.read_csv(os.path.join(path, 'flights2019.csv')).sample(250000, random_state = 11)

# %%
sample19.head()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 4706373     4706373  2019        3      8            16            5
# 1094369     1094369  2019        1      2            28            4
# 1663959     1663959  2019        1      3             3            7
# 1459243     1459243  2019        1      3            31            7
# 340728       340728  2019        1      1            25            5
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 4706373  2019-08-16                             DL
# 1094369  2019-02-28                             AA
# 1663959  2019-03-03                             WN
# 1459243  2019-03-31                             DL
# 340728   2019-01-25                             WN
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 4706373                          DL                9E  ...              3
# 1094369                          AA                PT  ...              1
# ...

# %%
sample19.tail()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 7509483     7509483  2019        4     12             2            1
# 6298968     6298968  2019        4     10            29            2
# 4674349     4674349  2019        3      7            27            6
# 1972149     1972149  2019        2      4            17            3
# 7532509     7532509  2019        4     12             7            6
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 7509483  2019-12-02                             AA
# 6298968  2019-10-29                             UA
# 4674349  2019-07-27                             UA
# 1972149  2019-04-17                             DL
# 7532509  2019-12-07                             F9
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 7509483                          AA                AA  ...              3
# 6298968                          UA                UA  ...             11
# ...

# %%
sample19.shape
# Out:
# (250000, 61)

# %%
# Drop the duplicate index column and drop additional columns irrelevant to what is needed for Tableau
sample19 = sample19.drop(columns=['Unnamed: 0', 'Origin_Airport_Seq_ID', 'Origin_City_Market_ID', 'Dest_Airport_Seq_ID',
                                  'Dest_City_Market_ID'])

# %%
sample19.shape
# Out:
# (250000, 56)

# %%
# Export 2019 Sample Data to CSV for Tableau analysis.

sample19.to_csv(os.path.join(path, 'Sample2019.csv'), index=False)  

# Specify index=False to avoid writing row numbers as a column

# %% [markdown]
# ## Now Creating Sample for 2020 Flight Data

# %%
#creating sample of 250,000 records from 2020 combined data

sample20 = pd.read_csv(os.path.join(path, 'flights2020.csv')).sample(250000, random_state = 11)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15560\2356013505.py:3: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   sample20 = pd.read_csv(os.path.join(path, 'flights2020.csv')).sample(250000, random_state = 11)

# %%
sample20.head()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 3862647     3862647  2020        4     10            20            2
# 2654512     2654512  2020        2      6            14            7
# 2020174     2020174  2020        2      4            15            3
# 972377       972377  2020        1      2            23            7
# 2558117     2558117  2020        2      6             7            7
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 3862647  2020-10-20                             UA
# 2654512  2020-06-14                             WN
# 2020174  2020-04-15                             AA
# 972377   2020-02-23                             DL
# 2558117  2020-06-07                             AA
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 3862647                          UA                YV  ...              5
# 2654512                          WN                WN  ...              2
# ...

# %%
sample20.tail()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 2409579     2409579  2020        2      5            15            5
# 3144533     3144533  2020        3      8             9            7
# 50656         50656  2020        1      1            13            1
# 1439325     1439325  2020        1      3            31            2
# 288311       288311  2020        1      1            29            3
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 2409579  2020-05-15                             G4
# 3144533  2020-08-09                             G4
# 50656    2020-01-13                             AA
# 1439325  2020-03-31                             B6
# 288311   2020-01-29                             DL
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 2409579                          G4                G4  ...              4
# 3144533                          G4                G4  ...              4
# ...

# %%
sample20.shape
# Out:
# (250000, 61)

# %%
# Drop the duplicate index column and drop additional columns irrelevant to what is needed for Tableau
sample20 = sample20.drop(columns=['Unnamed: 0', 'Origin_Airport_Seq_ID', 'Origin_City_Market_ID', 'Dest_Airport_Seq_ID',
                                  'Dest_City_Market_ID'])

# %%
sample20.shape
# Out:
# (250000, 56)

# %%
# Export 2020 Sample Data to CSV for Tableau analysis.

sample20.to_csv(os.path.join(path, 'Sample2020.csv'), index=False)  

# Specify index=False to avoid writing row numbers as a column

# %% [markdown]
# # Now creating sample for 2021 data

# %%
#creating sample of 250,000 records from 2021 combined data

sample21 = pd.read_csv(os.path.join(path, 'flights2021.csv')).sample(250000, random_state = 11)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15560\654194343.py:3: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   sample21 = pd.read_csv(os.path.join(path, 'flights2021.csv')).sample(250000, random_state = 11)

# %%
sample21.head()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 3800526     3800526  2021        3      8            16            1
# 6157463     6157463  2021        4     12            23            4
# 4462349     4462349  2021        3      9            14            2
# 2163394     2163394  2021        2      5            17            1
# 4494348     4494348  2021        3      9             8            3
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 3800526  2021-08-16                             AS
# 6157463  2021-12-23                             AA
# 4462349  2021-09-14                             WN
# 2163394  2021-05-17                             UA
# 4494348  2021-09-08                             WN
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 3800526                          AS                AS  ...             11
# 6157463                          AA                OH  ...              2
# ...

# %%
sample21.tail()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 2447975     2447975  2021        2      6            18            5
# 6161543     6161543  2021        4     12            14            2
# 2744250     2744250  2021        2      6             9            3
# 3641658     3641658  2021        3      8             6            5
# 2546328     2546328  2021        2      6             1            2
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 2447975  2021-06-18                             AA
# 6161543  2021-12-14                             AA
# 2744250  2021-06-09                             UA
# 3641658  2021-08-06                             UA
# 2546328  2021-06-01                             AA
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 2447975                          AA                MQ  ...              1
# 6161543                          AA                OH  ...              2
# ...

# %%
sample21.shape
# Out:
# (250000, 61)

# %%
# Drop the duplicate index column and drop additional columns irrelevant to what is needed for Tableau
sample21 = sample21.drop(columns=['Unnamed: 0', 'Origin_Airport_Seq_ID', 'Origin_City_Market_ID', 'Dest_Airport_Seq_ID',
                                  'Dest_City_Market_ID'])

# %%
sample21.shape
# Out:
# (250000, 56)

# %%
# Export 2021 Sample Data to CSV for Tableau analysis.

sample21.to_csv(os.path.join(path, 'Sample2021.csv'), index=False)  

# Specify index=False to avoid writing row numbers as a column

# %% [markdown]
# ## Creating Sample for 2022 Flight Data

# %%
#creating sample of 250,000 records from 2022 combined data

sample22 = pd.read_csv(os.path.join(path, 'flights2022.csv')).sample(250000, random_state = 11)

# %%
sample22.head()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 1523401     1523401  2022        1      3            13            7
# 2132092     2132092  2022        2      4            12            2
# 3762696     3762696  2022        3      7             4            1
# 1029211     1029211  2022        1      2            25            5
# 6022886     6022886  2022        4     11             9            3
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 1523401  2022-03-13                             UA
# 2132092  2022-04-12                             UA
# 3762696  2022-07-04                             AA
# 1029211  2022-02-25                             UA
# 6022886  2022-11-09                             DL
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 1523401                          UA                C5  ...              1
# 2132092                          UA                OO  ...              1
# ...

# %%
sample22.tail()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 2373234     2373234  2022        2      5             6            5
# 3593520     3593520  2022        3      7             4            1
# 496483       496483  2022        1      1            12            3
# 1273923     1273923  2022        1      3            22            2
# 4594072     4594072  2022        3      8            16            2
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 2373234  2022-05-06                             UA
# 3593520  2022-07-04                             UA
# 496483   2022-01-12                             UA
# 1273923  2022-03-22                             AA
# 4594072  2022-08-16                             DL
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 2373234                          UA                UA  ...              8
# 3593520                          UA                UA  ...              4
# ...

# %%
sample22.shape
# Out:
# (250000, 61)

# %%
# Drop the duplicate index column and drop additional columns irrelevant to what is needed for Tableau
sample22 = sample22.drop(columns=['Unnamed: 0', 'Origin_Airport_Seq_ID', 'Origin_City_Market_ID', 'Dest_Airport_Seq_ID',
                                  'Dest_City_Market_ID'])

# %%
sample22.shape
# Out:
# (250000, 56)

# %%
# Export 2022 Sample Data to CSV for Tableau analysis.

sample22.to_csv(os.path.join(path, 'Sample2022.csv'), index=False)  

# Specify index=False to avoid writing row numbers as a column

# %% [markdown]
# ## Creating Sample for 2023 Flight Data

# %%
#creating sample of 250,000 records from 2023 combined data

sample23 = pd.read_csv(os.path.join(path, 'flights2023.csv')).sample(250000, random_state = 11)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15560\3205908681.py:3: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   sample23 = pd.read_csv(os.path.join(path, 'flights2023.csv')).sample(250000, random_state = 11)

# %%
sample23.head()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 4541418     4541418  2023        3      8            19            6
# 3946324     3946324  2023        3      7             4            2
# 6218122     6218122  2023        4     11            21            2
# 6510926     6510926  2023        4     11            29            3
# 2135396     2135396  2023        2      4            21            5
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 4541418  2023-08-19                             AA
# 3946324  2023-07-04                             WN
# 6218122  2023-11-21                             WN
# 6510926  2023-11-29                             UA
# 2135396  2023-04-21                             AA
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 4541418                          AA                AA  ...              3
# 3946324                          WN                WN  ...              2
# ...

# %%
sample23.tail()
# Out:
#          Unnamed: 0  Year  Quarter  Month  Day_of_Month  Day_of_Week  \
# 2300496     2300496  2023        2      4            26            3
# 6917411     6917411  2023        4     12             8            5
# 742627       742627  2023        1      2            27            1
# 6611684     6611684  2023        4     11            12            7
# 204741       204741  2023        1      1            28            6
#
#         Flight_Date Marketing_Airline_Network_Code  \
# 2300496  2023-04-26                             DL
# 6917411  2023-12-08                             UA
# 742627   2023-02-27                             UA
# 6611684  2023-11-12                             F9
# 204741   2023-01-28                             AA
#
#         IATA_Code_Marketing_Airline Operating_Airline  ... Distance_Group  \
# 2300496                          DL                9E  ...              1
# 6917411                          UA                UA  ...              4
# ...

# %%
sample23.shape
# Out:
# (250000, 61)

# %%
# Drop the duplicate index column and drop additional columns irrelevant to what is needed for Tableau
sample23 = sample23.drop(columns=['Unnamed: 0', 'Origin_Airport_Seq_ID', 'Origin_City_Market_ID', 'Dest_Airport_Seq_ID',
                                  'Dest_City_Market_ID'])

# %%
sample23.shape
# Out:
# (250000, 56)

# %%
# Export 2023 Sample Data to CSV for Tableau analysis.

sample23.to_csv(os.path.join(path, 'Sample2023.csv'), index=False)  

# Specify index=False to avoid writing row numbers as a column

# %%
#concatinate samples to combine data for future analysis and data cleaning

samples_combined = pd.concat([sample19, sample20, sample21, sample22, sample23], axis=0)

# %%
samples_combined.head()
# Out:
#          Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 4706373  2019        3      8            16            5  2019-08-16
# 1094369  2019        1      2            28            4  2019-02-28
# 1663959  2019        1      3             3            7  2019-03-03
# 1459243  2019        1      3            31            7  2019-03-31
# 340728   2019        1      1            25            5  2019-01-25
#
#         Marketing_Airline_Network_Code IATA_Code_Marketing_Airline  \
# 4706373                             DL                          DL
# 1094369                             AA                          AA
# 1663959                             WN                          WN
# 1459243                             DL                          DL
# 340728                              WN                          WN
#
#         Operating_Airline IATA_Code_Operating_Airline  ... Distance_Group  \
# ...

# %%
samples_combined.tail()
# Out:
#          Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 2300496  2023        2      4            26            3  2023-04-26
# 6917411  2023        4     12             8            5  2023-12-08
# 742627   2023        1      2            27            1  2023-02-27
# 6611684  2023        4     11            12            7  2023-11-12
# 204741   2023        1      1            28            6  2023-01-28
#
#         Marketing_Airline_Network_Code IATA_Code_Marketing_Airline  \
# 2300496                             DL                          DL
# 6917411                             UA                          UA
# 742627                              UA                          UA
# 6611684                             F9                          F9
# 204741                              AA                          AA
#
#         Operating_Airline IATA_Code_Operating_Airline  ... Distance_Group  \
# ...

# %%
samples_combined.shape
# Out:
# (1250000, 56)

# %%
#export combined samples for Tableau Analysis

samples_combined.to_csv(os.path.join(path, 'Samples_Combined.csv'), index=False)  

# Specify index=False to avoid writing row numbers as a column
