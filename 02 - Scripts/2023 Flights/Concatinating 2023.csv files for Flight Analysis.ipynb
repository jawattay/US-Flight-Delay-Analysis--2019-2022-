# %%
import pandas as pd
import numpy as np
import os

# %%
# Set path

path = r'C:\Users\Josh Wattay\OneDrive\Documents\Desktop\Flight Delay Analysis - Raw Data\2023'

# %%
# Import Datasets

jan2023 = pd.read_csv(os.path.join(path, '1-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\2836491308.py:3: DtypeWarning: Columns (11,13,57,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2023 = pd.read_csv(os.path.join(path, '1-2023.csv'), index_col = False)

# %%
# Import Datasets

feb2023 = pd.read_csv(os.path.join(path, '2-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\1182875543.py:3: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   feb2023 = pd.read_csv(os.path.join(path, '2-2023.csv'), index_col = False)

# %%
# Import Datasets

mar2023 = pd.read_csv(os.path.join(path, '3-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\820702875.py:3: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   mar2023 = pd.read_csv(os.path.join(path, '3-2023.csv'), index_col = False)

# %%
# Import Datasets

apr2023 = pd.read_csv(os.path.join(path, '4-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\448314195.py:3: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   apr2023 = pd.read_csv(os.path.join(path, '4-2023.csv'), index_col = False)

# %%
# Import Datasets

may2023 = pd.read_csv(os.path.join(path, '5-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\879850055.py:3: DtypeWarning: Columns (11,13,86,93,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   may2023 = pd.read_csv(os.path.join(path, '5-2023.csv'), index_col = False)

# %%
# Import Datasets

jun2023 = pd.read_csv(os.path.join(path, '6-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\2038318949.py:3: DtypeWarning: Columns (11,13,86,93,94,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   jun2023 = pd.read_csv(os.path.join(path, '6-2023.csv'), index_col = False)

# %%
# Import Datasets

jul2023 = pd.read_csv(os.path.join(path, '7-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\851283316.py:3: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jul2023 = pd.read_csv(os.path.join(path, '7-2023.csv'), index_col = False)

# %%
# Import Datasets

aug2023 = pd.read_csv(os.path.join(path, '8-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\3021994675.py:3: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   aug2023 = pd.read_csv(os.path.join(path, '8-2023.csv'), index_col = False)

# %%
# Import Datasets

sep2023 = pd.read_csv(os.path.join(path, '9-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\2574026574.py:3: DtypeWarning: Columns (11,13,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   sep2023 = pd.read_csv(os.path.join(path, '9-2023.csv'), index_col = False)

# %%
# Import Datasets

oct2023 = pd.read_csv(os.path.join(path, '10-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\3625001011.py:3: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   oct2023 = pd.read_csv(os.path.join(path, '10-2023.csv'), index_col = False)

# %%
# Import Datasets

nov2023 = pd.read_csv(os.path.join(path, '11-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\4005808976.py:3: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   nov2023 = pd.read_csv(os.path.join(path, '11-2023.csv'), index_col = False)

# %%
# Import Datasets

dec2023 = pd.read_csv(os.path.join(path, '12-2023.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_2544\2873163579.py:3: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   dec2023 = pd.read_csv(os.path.join(path, '12-2023.csv'), index_col = False)

# %%
frames = [jan2023, feb2023, mar2023, apr2023, may2023, jun2023, jul2023, aug2023, sep2023, oct2023, nov2023, dec2023]

# %%
frames
# Out:
# [        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
#  0       2023        1      1          22          7  2023-01-22
#  1       2023        1      1          22          7  2023-01-22
#  2       2023        1      1          22          7  2023-01-22
#  3       2023        1      1          22          7  2023-01-22
#  4       2023        1      1          22          7  2023-01-22
#  ...      ...      ...    ...         ...        ...         ...
#  573872  2023        1      1           1          7  2023-01-01
#  573873  2023        1      1           1          7  2023-01-01
#  573874  2023        1      1           1          7  2023-01-01
#  573875  2023        1      1           1          7  2023-01-01
#  573876  2023        1      1           1          7  2023-01-01
#
#         Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
#  0                             B6                                      B6
# ...

# %%
type(frames)
# Out:
# list

# %%
#Concatinate the Dataframes using Default Options

flights2023 = pd.concat(frames)

# %%
flights2023.shape
# Out:
# (7278739, 120)

# %%
flights2023 = flights2023.drop(columns=[
    'Operated_or_Branded_Code_Share_Partners', 
    'Originally_Scheduled_Code_Share_Airline', 
    'DOT_ID_Originally_Scheduled_Code_Share_Airline',
    'Flight_Num_Originally_Scheduled_Code_Share_Airline',
    'OriginWac', 'DestWac', 'DivAirportLandings', 'DivReachedDest',
    'DivActualElapsedTime', 'DivArrDelay', 
    'Div1Airport', 'Div1AirportID',
    'Div1AirportSeqID', 'Div1WheelsOn', 'Div1TotalGTime', 
    'Div1LongestGTime', 'Div1WheelsOff', 'Div1TailNum',
    'Div2Airport', 'Div2AirportID',
    'Div2AirportSeqID', 'Div2WheelsOn', 'Div2TotalGTime', 
    'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum',
    'Div3Airport', 'Div3AirportID',
    'Div3AirportSeqID', 'Div3WheelsOn', 'Div3TotalGTime', 
    'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum',
    'Div4Airport', 'Div4AirportID',
    'Div4AirportSeqID', 'Div4WheelsOn', 'Div4TotalGTime', 
    'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum',
    'Div5Airport', 'Div5AirportID',
    'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime', 
    'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum', 'Unnamed: 119'])

# %%
flights2023.shape
# Out:
# (7278739, 69)

# %%
flights2023.to_csv(os.path.join(path, 'flights2023.csv'))
