# %% [markdown]
# # In This Notebook:
#
# ## 1. Overview of 2022 Flight Data
# ## 2. General Statistics
# ## 3. Temporal Analysis
# ## 4. Geospatial Analysis
# ## 5. Tail Number Analysis
# ## 6. Aggregation and Grouping (Wrangling)

# %%
#Import Libraries

import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Set Path

path = r'D:\Data Analytics\Flight Delay Analysis'

# %%
# Import 2022 Flight Data Set

df = pd.read_csv(os.path.join(path, '01 - Data', 'flights2022.csv'), index_col = 0)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_12796\2725048568.py:3: DtypeWarning: Columns (51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, '01 - Data', 'flights2022.csv'), index_col = 0)

# %% [markdown]
# ## 1. Overview of 2022 Flight Data

# %%
df.shape
# Out:
# (7013508, 66)

# %%
df.head()
# Out:
#    Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 0  2022        1      1             6            4  2022-01-06
# 1  2022        1      1             6            4  2022-01-06
# 2  2022        1      1             6            4  2022-01-06
# 3  2022        1      1             6            4  2022-01-06
# 4  2022        1      1             6            4  2022-01-06
#
#   Marketing_Airline_Network  DOT_ID_Marketing_Airline  \
# 0                        DL                     19790
# 1                        DL                     19790
# 2                        DL                     19790
# 3                        DL                     19790
# 4                        DL                     19790
#
#   IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  ... Distance  \
# 0                          DL                             1581  ...   1076.0
# 1                          DL                             1582  ...    581.0
# 2                          DL                             1582  ...    581.0
# 3                          DL                             1583  ...    680.0
# 4                          DL                             1584  ...    341.0
#
#    Distance_Group Carrier_Delay Weather_Delay  NAS_Delay  Security_Delay  \
# 0               5           NaN           NaN        NaN             NaN
# 1               3           NaN           NaN        NaN             NaN
# 2               3           NaN           NaN        NaN             NaN
# 3               3           NaN           NaN        NaN             NaN
# 4               2           NaN           NaN        NaN             NaN
#
#    Late_Aircraft_Delay  Duplicate Missing_Due_To_Cancellation  \
# 0                  NaN          N                        True
# 1                  NaN          N                       False
# 2                  NaN          N                       False
# 3                  NaN          N                       False
# 4                  NaN          N                       False
#
#                 Airline
# 0  Delta Air Lines Inc.
# 1  Delta Air Lines Inc.
# 2  Delta Air Lines Inc.
# 3  Delta Air Lines Inc.
# 4  Delta Air Lines Inc.
#
# [5 rows x 66 columns]

# %%
df.tail()
# Out:
#          Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 7013503  2022        4     12            27            2  2022-12-27
# 7013504  2022        4     12            28            3  2022-12-28
# 7013505  2022        4     12            29            4  2022-12-29
# 7013506  2022        4     12            30            5  2022-12-30
# 7013507  2022        4     12            31            6  2022-12-31
#
#         Marketing_Airline_Network  DOT_ID_Marketing_Airline  \
# 7013503                        NK                     20416
# 7013504                        NK                     20416
# 7013505                        NK                     20416
# 7013506                        NK                     20416
# 7013507                        NK                     20416
#
#         IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  ...  \
# 7013503                          NK                              913  ...
# 7013504                          NK                              913  ...
# 7013505                          NK                              913  ...
# 7013506                          NK                              913  ...
# 7013507                          NK                              913  ...
#
#         Distance  Distance_Group Carrier_Delay Weather_Delay  NAS_Delay  \
# 7013503   1363.0               6          22.0           0.0        1.0
# 7013504   1363.0               6           NaN           NaN        NaN
# 7013505   1363.0               6           0.0           0.0       11.0
# 7013506   1363.0               6           NaN           NaN        NaN
# 7013507   1363.0               6           NaN           NaN        NaN
#
#          Security_Delay  Late_Aircraft_Delay  Duplicate  \
# 7013503             0.0                 14.0          N
# 7013504             NaN                  NaN          N
# 7013505             0.0                 11.0          N
# 7013506             NaN                  NaN          N
# 7013507             NaN                  NaN          N
#
#         Missing_Due_To_Cancellation           Airline
# 7013503                       False  Spirit Air Lines
# 7013504                       False  Spirit Air Lines
# 7013505                       False  Spirit Air Lines
# 7013506                       False  Spirit Air Lines
# 7013507                       False  Spirit Air Lines
#
# [5 rows x 66 columns]

# %%
# Display the column names to verify

print("DF DataFrame Columns:", df.columns)
# Out:
# DF DataFrame Columns: Index(['Year', 'Quarter', 'Month', 'Day_of_Month', 'Day_of_Week',
#        'Flight_Date', 'Marketing_Airline_Network', 'DOT_ID_Marketing_Airline',
#        'IATA_Code_Marketing_Airline', 'Flight_Number_Marketing_Airline',
#        'Operating_Airline', 'DOT_ID_Operating_Airline',
#        'IATA_Code_Operating_Airline', 'Tail_Number',
#        'Flight_Number_Operating_Airline', 'Origin_Airport_ID',
#        'Origin_Airport_Seq_ID', 'Origin_City_Market_ID', 'Origin',
#        'Origin_City_Name', 'Origin_State', 'Origin_State_Fips',
#        'Origin_State_Name', 'Dest_Airport_ID', 'Dest_Airport_Seq_ID',
#        'Dest_City_Market_ID', 'Dest', 'Dest_City_Name', 'Dest_State',
#        'Dest_State_Fips', 'Dest_State_Name', 'CRS_Dep_Time', 'Dep_Time',
#        'Dep_Delay', 'Dep_Delay_Minutes', 'Dep_Del_15',
#        'Departure_Delay_Groups', 'Dep_Time_Blk', 'Taxi_Out', 'Wheels_Off',
#        'Wheels_On', 'Taxi_In', 'CRS_Arr_Time', 'Arr_Time', 'Arr_Delay',
#        'Arr_Delay_Minutes', 'Arr_Del_15', 'Arrival_Delay_Groups',
#        'Arr_Time_Blk', 'Cancelled', 'Cancellation_Code', 'Diverted',
#        'CRS_Elapsed_Time', 'Actual_Elapsed_Time', 'Air_Time', 'Flights',
#        'Distance', 'Distance_Group', 'Carrier_Delay', 'Weather_Delay',
#        'NAS_Delay', 'Security_Delay', 'Late_Aircraft_Delay', 'Duplicate',
#        'Missing_Due_To_Cancellation', 'Airline'],
#       dtype='object')

# %% [markdown]
# ## 2. General Statistics

# %%
df.describe()
# Out:
#             Year       Quarter         Month  Day_of_Month   Day_of_Week  \
# count  7013508.0  7.013508e+06  7.013508e+06  7.013508e+06  7.013508e+06
# mean      2022.0  2.516275e+00  6.547852e+00  1.573387e+01  3.982934e+00
# std          0.0  1.106200e+00  3.406279e+00  8.783559e+00  2.001696e+00
# min       2022.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2022.0  2.000000e+00  4.000000e+00  8.000000e+00  2.000000e+00
# 50%       2022.0  3.000000e+00  7.000000e+00  1.600000e+01  4.000000e+00
# 75%       2022.0  3.000000e+00  9.000000e+00  2.300000e+01  6.000000e+00
# max       2022.0  4.000000e+00  1.200000e+01  3.100000e+01  7.000000e+00
#
#        DOT_ID_Marketing_Airline  Flight_Number_Marketing_Airline  \
# count              7.013508e+06                     7.013508e+06
# mean               1.982885e+04                     2.503782e+03
# std                2.794990e+02                     1.718253e+03
# min                1.939300e+04                     1.000000e+00
# 25%                1.979000e+04                     1.084000e+03
# 50%                1.980500e+04                     2.180000e+03
# 75%                1.997700e+04                     3.764000e+03
# max                2.043600e+04                     9.680000e+03
#
#        DOT_ID_Operating_Airline  Flight_Number_Operating_Airline  \
# count              7.013508e+06                     7.013508e+06
# mean               1.998082e+04                     2.503779e+03
# std                3.771087e+02                     1.718269e+03
# min                1.939300e+04                     1.000000e+00
# 25%                1.979000e+04                     1.084000e+03
# 50%                1.997700e+04                     2.180000e+03
# 75%                2.037800e+04                     3.764000e+03
# max                2.050000e+04                     9.680000e+03
#
#        Origin_Airport_ID  ...  Actual_Elapsed_Time      Air_Time    Flights  \
# count       7.013508e+06  ...         6.806806e+06  6.806806e+06  7013508.0
# mean        1.265782e+04  ...         1.355721e+02  1.106410e+02        1.0
# std         1.523170e+03  ...         7.177725e+01  6.982750e+01        0.0
# min         1.013500e+04  ...         1.400000e+01  8.000000e+00        1.0
# 25%         1.129200e+04  ...         8.300000e+01  6.000000e+01        1.0
# 50%         1.288900e+04  ...         1.180000e+02  9.300000e+01        1.0
# 75%         1.402700e+04  ...         1.660000e+02  1.400000e+02        1.0
# max         1.686900e+04  ...         7.640000e+02  7.270000e+02        1.0
#
#            Distance  Distance_Group  Carrier_Delay  Weather_Delay  \
# count  7.013508e+06    7.013508e+06   1.426305e+06   1.426305e+06
# mean   7.969464e+02    3.659272e+00   2.675455e+01   3.823167e+00
# std    5.918063e+02    2.322547e+00   7.518814e+01   3.124671e+01
# min    3.100000e+01    1.000000e+00   0.000000e+00   0.000000e+00
# 25%    3.680000e+02    2.000000e+00   0.000000e+00   0.000000e+00
# 50%    6.410000e+02    3.000000e+00   7.000000e+00   0.000000e+00
# 75%    1.032000e+03    5.000000e+00   2.600000e+01   0.000000e+00
# max    5.095000e+03    1.100000e+01   7.232000e+03   2.363000e+03
#
#           NAS_Delay  Security_Delay  Late_Aircraft_Delay
# count  1.426305e+06    1.426305e+06         1.426305e+06
# mean   1.141125e+01    1.385209e-01         2.561720e+01
# std    2.898008e+01    3.640329e+00         5.630912e+01
# min    0.000000e+00    0.000000e+00         0.000000e+00
# 25%    0.000000e+00    0.000000e+00         0.000000e+00
# 50%    0.000000e+00    0.000000e+00         0.000000e+00
# 75%    1.500000e+01    0.000000e+00         3.000000e+01
# max    1.740000e+03    1.245000e+03         2.302000e+03
#
# [8 rows x 46 columns]

# %%
# Calculate general statistics for delays and cancellations
delay_stats = df[['Dep_Delay', 'Arr_Delay', 'Cancelled', 'Diverted']].describe()
print(delay_stats)
# Out:
#           Dep_Delay     Arr_Delay     Cancelled      Diverted
# count  6.827656e+06  6.806806e+06  7.013508e+06  7.013508e+06
# mean   1.248283e+01  6.963227e+00  2.709600e-02  2.375844e-03
# std    5.295994e+01  5.479529e+01  1.623632e-01  4.868470e-02
# min   -9.600000e+01 -1.000000e+02  0.000000e+00  0.000000e+00
# 25%   -5.000000e+00 -1.400000e+01  0.000000e+00  0.000000e+00
# 50%   -2.000000e+00 -5.000000e+00  0.000000e+00  0.000000e+00
# 75%    1.000000e+01  1.000000e+01  0.000000e+00  0.000000e+00
# max    7.223000e+03  7.232000e+03  1.000000e+00  1.000000e+00

# %%
# Identify the most common delay reasons and cancellation codes
common_delays = df[['Carrier_Delay', 'Weather_Delay', 'NAS_Delay', 'Security_Delay', 'Late_Aircraft_Delay']].sum()
print(common_delays)
# Out:
# Carrier_Delay          38160150.0
# Weather_Delay           5453002.0
# NAS_Delay              16275923.0
# Security_Delay           197573.0
# Late_Aircraft_Delay    36537941.0
# dtype: float64

# %%
common_cancellation_codes = df['Cancellation_Code'].value_counts()
print(common_cancellation_codes)
# Out:
# Cancellation_Code
# B    100374
# A     72733
# C     15874
# D      1057
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Temporal Analysis

# %%
# Analyze delays and cancellations by day of the week

delays_by_day = df.groupby('Day_of_Week')[['Dep_Delay', 'Arr_Delay']].mean()
print(delays_by_day)
# Out:
#              Dep_Delay  Arr_Delay
# Day_of_Week
# 1            12.618138   7.114627
# 2             9.255678   3.116066
# 3             9.421793   3.713576
# 4            12.816140   7.989244
# 5            15.040607  10.304144
# 6            13.846019   7.568784
# 7            14.275100   8.706301

# %%
cancellations_by_day = df.groupby('Day_of_Week')['Cancelled'].sum()
print(cancellations_by_day)
# Out:
# Day_of_Week
# 1    25491.0
# 2    16670.0
# 3    22929.0
# 4    35168.0
# 5    34565.0
# 6    27010.0
# 7    28205.0
# Name: Cancelled, dtype: float64

# %%
# Analyze delays and cancellations by month
delays_by_month = df.groupby('Month')[['Dep_Delay', 'Arr_Delay']].mean()
print(delays_by_month)
# Out:
#        Dep_Delay  Arr_Delay
# Month
# 1      11.098772   4.221933
# 2      11.303938   4.838776
# 3      12.472167   6.967127
# 4      13.226058   8.307427
# 5      12.460675   7.356645
# 6      15.716603  10.566019
# 7      14.836005   9.665443
# 8      13.908255   8.581241
# 9       8.321554   2.307862
# 10      8.000408   2.015657
# 11      9.944321   4.742281
# 12     18.313446  13.597530

# %%
cancellations_by_month = df.groupby('Month')['Cancelled'].sum()
print(cancellations_by_month)
# Out:
# Month
# 1     35667.0
# 2     23421.0
# 3      9108.0
# 4     13397.0
# 5     11993.0
# 6     18473.0
# 7     11133.0
# 8     15483.0
# 9      8858.0
# 10     4878.0
# 11     6440.0
# 12    31187.0
# Name: Cancelled, dtype: float64

# %%
# Analyze delays and cancellations by quarter

delays_by_quarter = df.groupby('Quarter')[['Dep_Delay', 'Arr_Delay']].mean()
print(delays_by_quarter)
# Out:
#          Dep_Delay  Arr_Delay
# Quarter
# 1        11.659377   5.406223
# 2        13.801200   8.741443
# 3        12.429523   6.932781
# 4        11.965251   6.645154

# %%
cancellations_by_quarter = df.groupby('Quarter')['Cancelled'].sum()
print(cancellations_by_quarter)
# Out:
# Quarter
# 1    68196.0
# 2    43863.0
# 3    35474.0
# 4    42505.0
# Name: Cancelled, dtype: float64

# %% [markdown]
# ## 4. Geospatial Analysis

# %%
# Determine the origin and destination airports with the highest delays and cancellations

origin_delays = df.groupby('Origin_City_Name')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Dep_Delay', ascending=False)
print(origin_delays.head(10))
# Out:
#                    Dep_Delay  Arr_Delay
# Origin_City_Name
# Watertown, SD      49.000000  32.500000
# Pago Pago, TT      41.888889  44.972222
# Wilmington, DE     32.904762  32.380952
# Stockton, CA       32.340000  35.490818
# Bishop, CA         29.907643  20.487261
# Santa Maria, CA    29.884615  35.246154
# Niagara Falls, NY  27.231959  29.581395
# Aspen, CO          27.078398  21.892012
# Ogdensburg, NY     26.399142  20.047210
# Rockford, IL       25.641379  26.812760

# %%
destination_delays = df.groupby('Dest_City_Name')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Arr_Delay', ascending=False)
print(destination_delays.head(10))
# Out:
#                           Dep_Delay   Arr_Delay
# Dest_City_Name
# Bullhead City, AZ         -9.000000  222.000000
# Watertown, SD             58.000000   46.000000
# Pago Pago, TT             39.527778   39.236111
# Punta Gorda, FL           26.800171   33.203300
# Aguadilla, PR             30.081974   26.648451
# Presque Isle/Houlton, ME  28.593368   25.822183
# Wilmington, DE            24.418605   25.190476
# Bishop, CA                27.771429   23.343949
# Sanford, FL               21.883229   22.879344
# St. Petersburg, FL        19.024771   21.720234

# %%
# Identify the airlines with the highest delays and cancellations
airline_delays = df.groupby('Airline')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Dep_Delay', ascending=False)
print(airline_delays)
# Out:
#                                            Dep_Delay  Arr_Delay
# Airline
# JetBlue Airways                            23.209662  18.177021
# Frontier Airlines Inc.                     21.163469  17.393118
# Allegiant Air                              18.493799  19.482973
# Mesa Airlines Inc.                         15.955559   9.329786
# American Airlines Inc.                     15.100316  10.074988
# GoJet Airlines, LLC d/b/a United Express   14.527927  10.696249
# Southwest Airlines Co.                     14.456217   7.128830
# Spirit Air Lines                           14.277110  10.110602
# United Air Lines Inc.                      12.451999   5.372875
# Commutair Aka Champlain Enterprises, Inc.  11.142111   7.040487
# SkyWest Airlines Inc.                      10.448082   5.390469
# Air Wisconsin Airlines Corp                10.206941   3.879926
# Delta Air Lines Inc.                        9.985473   2.625578
# Hawaiian Airlines Inc.                      9.927646   8.722278
# Comair Inc.                                 9.755143   6.299414
# Endeavor Air Inc.                           9.269983   3.475101
# Republic Airlines                           8.514774   4.578748
# Envoy Air                                   7.286946   3.408491
# Alaska Airlines Inc.                        6.618878   3.770009
# Horizon Air                                 6.333013   4.641131
# Capital Cargo International                 3.924456   0.509714

# %%
airline_cancellations = df.groupby('Airline')['Cancelled'].sum().sort_values(ascending=False)
print(airline_cancellations)
# Out:
# Airline
# Southwest Airlines Co.                       42655.0
# American Airlines Inc.                       25894.0
# Republic Airlines                            14832.0
# Delta Air Lines Inc.                         14317.0
# SkyWest Airlines Inc.                        13218.0
# United Air Lines Inc.                        11886.0
# JetBlue Airways                              10219.0
# Endeavor Air Inc.                             8196.0
# Spirit Air Lines                              6973.0
# Comair Inc.                                   6547.0
# Alaska Airlines Inc.                          6218.0
# Envoy Air                                     5466.0
# Frontier Airlines Inc.                        4455.0
# Allegiant Air                                 4110.0
# Mesa Airlines Inc.                            3744.0
# GoJet Airlines, LLC d/b/a United Express      3248.0
# Air Wisconsin Airlines Corp                   2184.0
# Commutair Aka Champlain Enterprises, Inc.     1909.0
# Capital Cargo International                   1775.0
# Horizon Air                                   1512.0
# Hawaiian Airlines Inc.                         680.0
# Name: Cancelled, dtype: float64

# %% [markdown]
# ## 5. Tail Number Analysis

# %%
# Check if specific aircraft tail numbers are more prone to delays or cancellations
tail_number_delays = df.groupby('Tail_Number')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Dep_Delay', ascending=False)
print(tail_number_delays.head(10))
# Out:
#               Dep_Delay   Arr_Delay
# Tail_Number
# N37545       134.750000  115.000000
# N4022J       129.000000  125.000000
# N804AN        78.336634   74.801980
# N413DX        78.000000   76.058824
# N881BK        63.555556   56.888889
# N1808U        62.200000   62.480000
# N12020        60.900000   39.300000
# N14019        58.300000   58.000000
# N4058J        58.000000   75.750000
# N3115J        57.344828   45.724138

# %%
tail_number_cancellations = df.groupby('Tail_Number')['Cancelled'].sum().sort_values(ascending=False)
print(tail_number_cancellations.head(10))
# Out:
# Tail_Number
# Unknown    42208.0
# N725YX       116.0
# N284JB       111.0
# N727YX       110.0
# N731YX       109.0
# N482PX       107.0
# N329JB       105.0
# N746YX       104.0
# N203JQ       103.0
# N192JB       103.0
# Name: Cancelled, dtype: float64

# %% [markdown]
# ## 6. Aggregation and Grouping (Wrangling)

# %%
# Group by various metrics to gain insights
grouped_by_airline = df.groupby('Airline').agg({
    'Dep_Delay': 'mean',
    'Arr_Delay': 'mean',
    'Cancelled': 'sum'
}).sort_values(by='Dep_Delay', ascending=False)
print(grouped_by_airline)
# Out:
#                                            Dep_Delay  Arr_Delay  Cancelled
# Airline
# JetBlue Airways                            23.209662  18.177021    10219.0
# Frontier Airlines Inc.                     21.163469  17.393118     4455.0
# Allegiant Air                              18.493799  19.482973     4110.0
# Mesa Airlines Inc.                         15.955559   9.329786     3744.0
# American Airlines Inc.                     15.100316  10.074988    25894.0
# GoJet Airlines, LLC d/b/a United Express   14.527927  10.696249     3248.0
# Southwest Airlines Co.                     14.456217   7.128830    42655.0
# Spirit Air Lines                           14.277110  10.110602     6973.0
# United Air Lines Inc.                      12.451999   5.372875    11886.0
# Commutair Aka Champlain Enterprises, Inc.  11.142111   7.040487     1909.0
# SkyWest Airlines Inc.                      10.448082   5.390469    13218.0
# Air Wisconsin Airlines Corp                10.206941   3.879926     2184.0
# Delta Air Lines Inc.                        9.985473   2.625578    14317.0
# Hawaiian Airlines Inc.                      9.927646   8.722278      680.0
# Comair Inc.                                 9.755143   6.299414     6547.0
# Endeavor Air Inc.                           9.269983   3.475101     8196.0
# Republic Airlines                           8.514774   4.578748    14832.0
# Envoy Air                                   7.286946   3.408491     5466.0
# Alaska Airlines Inc.                        6.618878   3.770009     6218.0
# Horizon Air                                 6.333013   4.641131     1512.0
# Capital Cargo International                 3.924456   0.509714     1775.0

# %%
grouped_by_airport = df.groupby('Origin_City_Name').agg({
    'Dep_Delay': 'mean',
    'Arr_Delay': 'mean',
    'Cancelled': 'sum'
}).sort_values(by='Dep_Delay', ascending=False)
print(grouped_by_airport)
# Out:
#                   Dep_Delay  Arr_Delay  Cancelled
# Origin_City_Name
# Watertown, SD     49.000000  32.500000        0.0
# Pago Pago, TT     41.888889  44.972222        0.0
# Wilmington, DE    32.904762  32.380952        5.0
# Stockton, CA      32.340000  35.490818       15.0
# Bishop, CA        29.907643  20.487261       11.0
# ...                     ...        ...        ...
# Kodiak, AK        -3.959206  -0.625138       42.0
# Kotzebue, AK      -5.353891  -4.610294       43.0
# Pierre, SD        -7.000000 -16.500000        1.0
# Gustavus, AK      -8.198113  -7.273585        4.0
# Saipan, TT        -8.819121  -8.439276        0.0
#
# [369 rows x 3 columns]

# %%
# Import Seaborn for Visualizations

import seaborn as sns

# %%
# Ensure that Flight Date is in datetime format

df['Flight_Date'] = pd.to_datetime(df['Flight_Date'])
df_2022 = df[df['Flight_Date'].dt.year == 2022]

# %%
# Set save path for saving visuals

save_path = os.path.join(path, '03 - Visuals')

# %%
# Delays by Day of the Week
delays_by_day = df_2022.groupby('Day_of_Week')[['Dep_Delay', 'Arr_Delay']].mean()
delays_by_day.plot(kind='bar', figsize=(10, 6), title='2022 Average Delays by Day of the Week')
plt.ylabel('Average Delay (minutes)')
plt.savefig(f'{save_path}delays_by_day_of_week_2022.png')
plt.show()

# %%
delays_by_quarter = df_2022.groupby('Quarter')[['Dep_Delay', 'Arr_Delay']].mean()

# %%
# Plot the delays by quarter
delays_by_quarter.plot(kind='bar', figsize=(10, 6), title='2022 Average Delays by Quarter')
plt.ylabel('Average Delay (minutes)')
plt.xlabel('Quarter')
plt.tight_layout()  # Adjust layout to prevent clipping
plt.savefig(f'{save_path}delays_by_quarter_2022.png')
plt.show()

# %%
# Cancellations by Day of the Week
cancellations_by_day = df_2022.groupby('Day_of_Week')['Cancelled'].sum()
ax = cancellations_by_day.plot(kind='bar', figsize=(10, 6), title='2022 Cancellations by Day of the Week', color='red')
plt.ylabel('Number of Cancellations')
plt.savefig(f'{save_path}cancellations_by_day_of_week_2022.png')
plt.show()

# %%
# Monthly Trends
delays_by_month = df_2022.groupby('Month')[['Dep_Delay', 'Arr_Delay']].mean()
ax = delays_by_month.plot(kind='line', figsize=(10, 6), title='2022 Average Delays by Month')
plt.ylabel('Average Delay (minutes)')
plt.savefig(f'{save_path}delays_by_month_2022.png')
plt.show()

# %%
# Monthly Cancellation Trends
cancellations_by_month = df_2022.groupby('Month')[['Cancelled']].sum()
ax = cancellations_by_month.plot(kind='line', figsize=(10, 6), title='2022 Cancellations by Month')
plt.ylabel('Number of Cancellations')
plt.savefig(f'{save_path}cancellations_by_month_2022.png')
plt.show()

# %%
# Dictionary mapping abbreviations to full names
airline_mapping = {
    'AA': 'American Airlines Inc.',
    'AS': 'Alaska Airlines Inc.',
    'B6': 'JetBlue Airways',
    'DL': 'Delta Air Lines Inc.',
    'F9': 'Frontier Airlines Inc.',
    'G4': 'Allegiant Air',
    'HA': 'Hawaiian Airlines Inc.',
    'NK': 'Spirit Air Lines',
    'UA': 'United Airlines Inc.',
    'VX': 'Virgin America',
    'WN': 'Southwest Airlines Co.'
}

# %%
# Add a new column with full names
df_2022['Marketing_Airline_Network_Full'] = df_2022['Marketing_Airline_Network'].map(airline_mapping)

# %%
# Rename columns
df_2022 = df_2022.rename(columns={
    'Marketing_Airline_Network': 'Marketing_Airline_Network_Code',
    'Marketing_Airline_Network_Full': 'Marketing_Airline_Network'
})

# %%
# Distribution of Delays by Marketing Airline Network
plt.figure(figsize=(16, 10))  # Increase the width and height of the figure
sns.boxplot(x='Marketing_Airline_Network', y='Dep_Delay', data=df_2022)
plt.title('2022 Distribution of Departure Delays by Marketing Airline Network', fontsize=16)
plt.ylabel('Departure Delay (minutes)', fontsize=14)
plt.xlabel('Marketing Airline Network', fontsize=14)
plt.xticks(rotation=45, fontsize=10)  # Rotate labels and adjust font size
plt.tight_layout()  # Adjust layout to prevent clipping
plt.savefig(f'{save_path}delays_by_airline_network_boxplot_2022.png')
plt.show()

# %% [markdown]
# ## I will be using Tableau for further Geospatial Analsysis.

# %%
# Count the number of flights per month using the existing 'Month' column
flights_per_month = df_2022['Month'].value_counts().sort_index()

# %%
# Plot the line chart

ax = flights_per_month.plot(kind='line', figsize=(10, 6), title='2022 Flights per Month')
plt.ylabel('Number of Flights')
plt.savefig(f'{save_path}flights_per_month_2022.png')
plt.show()

# %%
# Save 2022 flights dataframe, now with Marketing_Airline_Network & Marketing_Airline_Network_Code columns

df_2022.to_csv(os.path.join(path, 'flights2022.csv'))
