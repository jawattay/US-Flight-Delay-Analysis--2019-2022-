# %%
import pandas as pd
import numpy as np
import os

# %%
# Set path

path = r'C:\Users\Josh Wattay\OneDrive\Documents\Desktop\Flight Delay Analysis - Raw Data\2022'

# %%
# Import Datasets

jan2022 = pd.read_csv(os.path.join(path, '1-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\3280920030.py:3: DtypeWarning: Columns (11,13,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2022 = pd.read_csv(os.path.join(path, '1-2022.csv'), index_col = False)

# %%
# Import Datasets

feb2022 = pd.read_csv(os.path.join(path, '2-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\1586372324.py:3: DtypeWarning: Columns (11,13,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   feb2022 = pd.read_csv(os.path.join(path, '2-2022.csv'), index_col = False)

# %%
# Import Datasets

mar2022 = pd.read_csv(os.path.join(path, '3-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\1963545753.py:3: DtypeWarning: Columns (11,13,86,93,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   mar2022 = pd.read_csv(os.path.join(path, '3-2022.csv'), index_col = False)

# %%
# Import Datasets

apr2022 = pd.read_csv(os.path.join(path, '4-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\587041710.py:3: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   apr2022 = pd.read_csv(os.path.join(path, '4-2022.csv'), index_col = False)

# %%
# Import Datasets

may2022 = pd.read_csv(os.path.join(path, '5-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\3535474083.py:3: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   may2022 = pd.read_csv(os.path.join(path, '5-2022.csv'), index_col = False)

# %%
# Import Datasets

jun2022 = pd.read_csv(os.path.join(path, '6-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\1637288610.py:3: DtypeWarning: Columns (11,13,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jun2022 = pd.read_csv(os.path.join(path, '6-2022.csv'), index_col = False)

# %%
# Import Datasets

jul2022 = pd.read_csv(os.path.join(path, '7-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\3700451642.py:3: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jul2022 = pd.read_csv(os.path.join(path, '7-2022.csv'), index_col = False)

# %%
# Import Datasets

aug2022 = pd.read_csv(os.path.join(path, '8-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\758977663.py:3: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   aug2022 = pd.read_csv(os.path.join(path, '8-2022.csv'), index_col = False)

# %%
# Import Datasets

sep2022 = pd.read_csv(os.path.join(path, '9-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\2217835209.py:3: DtypeWarning: Columns (11,13,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   sep2022 = pd.read_csv(os.path.join(path, '9-2022.csv'), index_col = False)

# %%
# Import Datasets

oct2022 = pd.read_csv(os.path.join(path, '10-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\1936777742.py:3: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   oct2022 = pd.read_csv(os.path.join(path, '10-2022.csv'), index_col = False)

# %%
# Import Datasets

nov2022 = pd.read_csv(os.path.join(path, '11-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\3152586911.py:3: DtypeWarning: Columns (11,13,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   nov2022 = pd.read_csv(os.path.join(path, '11-2022.csv'), index_col = False)

# %%
# Import Datasets

dec2022 = pd.read_csv(os.path.join(path, '12-2022.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_9888\541703496.py:3: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   dec2022 = pd.read_csv(os.path.join(path, '12-2022.csv'), index_col = False)

# %%
frames = [jan2022, feb2022, mar2022, apr2022, may2022, jun2022, jul2022, aug2022, sep2022, oct2022, nov2022, dec2022]

# %%
frames
# Out:
# [        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
#  0       2022        1      1           6          4  2022-01-06
#  1       2022        1      1           6          4  2022-01-06
#  2       2022        1      1           6          4  2022-01-06
#  3       2022        1      1           6          4  2022-01-06
#  4       2022        1      1           6          4  2022-01-06
#  ...      ...      ...    ...         ...        ...         ...
#  563732  2022        1      1          24          1  2022-01-24
#  563733  2022        1      1          24          1  2022-01-24
#  563734  2022        1      1          24          1  2022-01-24
#  563735  2022        1      1          24          1  2022-01-24
#  563736  2022        1      1          24          1  2022-01-24
#
#         Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
#  0                             DL                                      DL
# ...

# %%
type(frames)
# Out:
# list

# %%
#Concatinate the Dataframes using Default Options

flights2022 = pd.concat(frames)

# %%
flights2022.shape
# Out:
# (7013508, 120)

# %%
flights2022 = flights2022.drop(columns=[
    'Operated_or_Branded_Code_Share_Partners', 
    'Originally_Scheduled_Code_Share_Airline', 
    'DOT_ID_Originally_Scheduled_Code_Share_Airline',
    'Flight_Num_Originally_Scheduled_Code_Share_Airline',
    'OriginWac', 'DestWac', 'DivAirportLandings', 'DivReachedDest',
    'DivActualElapsedTime', 'DivArrDelay', 
    'Div1Airport', 'Div1AirportID',
    'Div1AirportSeqID', 'Div1WheelsOn', 'Div1TotalGTime', 
    'Div1LongestGTime', 'Div1WheelsOff', 'Div1TailNum',
    'Div2Airport', 'Div2AirportID',
    'Div2AirportSeqID', 'Div2WheelsOn', 'Div2TotalGTime', 
    'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum',
    'Div3Airport', 'Div3AirportID',
    'Div3AirportSeqID', 'Div3WheelsOn', 'Div3TotalGTime', 
    'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum',
    'Div4Airport', 'Div4AirportID',
    'Div4AirportSeqID', 'Div4WheelsOn', 'Div4TotalGTime', 
    'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum',
    'Div5Airport', 'Div5AirportID',
    'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime', 
    'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum', 'Unnamed: 119'])

# %%
flights2022.shape
# Out:
# (7013508, 69)

# %%
flights2022.to_csv(os.path.join(path, 'flights2022.csv'))
