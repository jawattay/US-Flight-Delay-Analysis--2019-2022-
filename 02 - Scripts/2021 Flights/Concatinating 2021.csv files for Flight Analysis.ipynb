# %%
import pandas as pd
import numpy as np
import os

# %%
# Set path

path = r'C:\Users\Josh Wattay\OneDrive\Documents\Desktop\Flight Delay Analysis - Raw Data\2021'

# %%
# Import Datasets

jan2021 = pd.read_csv(os.path.join(path, '1-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\1388993820.py:3: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2021 = pd.read_csv(os.path.join(path, '1-2021.csv'), index_col = False)

# %%
feb2021 = pd.read_csv(os.path.join(path, '2-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\846456926.py:1: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   feb2021 = pd.read_csv(os.path.join(path, '2-2021.csv'), index_col = False)

# %%
mar2021 = pd.read_csv(os.path.join(path, '3-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\3170488402.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   mar2021 = pd.read_csv(os.path.join(path, '3-2021.csv'), index_col = False)

# %%
apr2021 = pd.read_csv(os.path.join(path, '4-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\3382291140.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   apr2021 = pd.read_csv(os.path.join(path, '4-2021.csv'), index_col = False)

# %%
may2021 = pd.read_csv(os.path.join(path, '5-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\3413279217.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   may2021 = pd.read_csv(os.path.join(path, '5-2021.csv'), index_col = False)

# %%
jun2021 = pd.read_csv(os.path.join(path, '6-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\527969207.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jun2021 = pd.read_csv(os.path.join(path, '6-2021.csv'), index_col = False)

# %%
jul2021 = pd.read_csv(os.path.join(path, '7-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\3958607915.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jul2021 = pd.read_csv(os.path.join(path, '7-2021.csv'), index_col = False)

# %%
aug2021 = pd.read_csv(os.path.join(path, '8-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\1423738176.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   aug2021 = pd.read_csv(os.path.join(path, '8-2021.csv'), index_col = False)

# %%
sep2021 = pd.read_csv(os.path.join(path, '9-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\3529784559.py:1: DtypeWarning: Columns (11,13,57,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   sep2021 = pd.read_csv(os.path.join(path, '9-2021.csv'), index_col = False)

# %%
oct2021 = pd.read_csv(os.path.join(path, '10-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\18331742.py:1: DtypeWarning: Columns (11,13,57,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   oct2021 = pd.read_csv(os.path.join(path, '10-2021.csv'), index_col = False)

# %%
nov2021 = pd.read_csv(os.path.join(path, '11-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\2780134695.py:1: DtypeWarning: Columns (11,13,57,86) have mixed types. Specify dtype option on import or set low_memory=False.
#   nov2021 = pd.read_csv(os.path.join(path, '11-2021.csv'), index_col = False)

# %%
dec2021 = pd.read_csv(os.path.join(path, '12-2021.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_14184\1432330053.py:1: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   dec2021 = pd.read_csv(os.path.join(path, '12-2021.csv'), index_col = False)

# %%
frames = [jan2021, feb2021, mar2021, apr2021, may2021, jun2021, jul2021, aug2021, sep2021, oct2021, nov2021, dec2021]

# %%
frames
# Out:
# [        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
#  0       2021        1      1           2          6  2021-01-02
#  1       2021        1      1           3          7  2021-01-03
#  2       2021        1      1           4          1  2021-01-04
#  3       2021        1      1           7          4  2021-01-07
#  4       2021        1      1           8          5  2021-01-08
#  ...      ...      ...    ...         ...        ...         ...
#  379379  2021        1      1          30          6  2021-01-30
#  379380  2021        1      1          30          6  2021-01-30
#  379381  2021        1      1          31          7  2021-01-31
#  379382  2021        1      1          31          7  2021-01-31
#  379383  2021        1      1          31          7  2021-01-31
#
#         Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
#  0                             DL                            DL_CODESHARE
# ...

# %%
type(frames)
# Out:
# list

# %%
#Concatinate the Dataframes using Default Options

flights2021 = pd.concat(frames)

# %%
flights2021.shape
# Out:
# (6311871, 120)

# %%
flights2021 = flights2021.drop(columns=[
    'Operated_or_Branded_Code_Share_Partners', 
    'Originally_Scheduled_Code_Share_Airline', 
    'DOT_ID_Originally_Scheduled_Code_Share_Airline',
    'Flight_Num_Originally_Scheduled_Code_Share_Airline',
    'OriginWac', 'DestWac', 'DivAirportLandings', 'DivReachedDest',
    'DivActualElapsedTime', 'DivArrDelay', 
    'Div1Airport', 'Div1AirportID',
    'Div1AirportSeqID', 'Div1WheelsOn', 'Div1TotalGTime', 
    'Div1LongestGTime', 'Div1WheelsOff', 'Div1TailNum',
    'Div2Airport', 'Div2AirportID',
    'Div2AirportSeqID', 'Div2WheelsOn', 'Div2TotalGTime', 
    'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum',
    'Div3Airport', 'Div3AirportID',
    'Div3AirportSeqID', 'Div3WheelsOn', 'Div3TotalGTime', 
    'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum',
    'Div4Airport', 'Div4AirportID',
    'Div4AirportSeqID', 'Div4WheelsOn', 'Div4TotalGTime', 
    'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum',
    'Div5Airport', 'Div5AirportID',
    'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime', 
    'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum', 'Unnamed: 119'])

# %%
flights2021.shape
# Out:
# (6311871, 69)

# %%
flights2021.to_csv(os.path.join(path, 'flights2021.csv'))
