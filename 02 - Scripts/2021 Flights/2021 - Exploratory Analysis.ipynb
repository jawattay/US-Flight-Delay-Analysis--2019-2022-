# %% [markdown]
# # In This Notebook:
#
# ## 1. Overview of 2021 Flight Data
# ## 2. General Statistics
# ## 3. Temporal Analysis
# ## 4. Geospatial Analysis
# ## 5. Tail Number Analysis
# ## 6. Aggregation and Grouping (Wrangling)

# %%
#Import Libraries

import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Set Path

path = r'C:\Users\Josh Wattay\OneDrive\Documents\Desktop\Flight Delay Analysis'

# %%
# Import 2021 Flight Data Set

df = pd.read_csv(os.path.join(path, '01 - Data', 'flights2021.csv'), index_col = 0)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3516\1610666521.py:3: DtypeWarning: Columns (51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, '01 - Data', 'flights2021.csv'), index_col = 0)

# %% [markdown]
# ## 1. Overview of 2021 Flight Data

# %%
df.shape
# Out:
# (6311871, 66)

# %%
df.head()
# Out:
#    Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 0  2021        1      1             2            6  2021-01-02
# 1  2021        1      1             3            7  2021-01-03
# 2  2021        1      1             4            1  2021-01-04
# 3  2021        1      1             7            4  2021-01-07
# 4  2021        1      1             8            5  2021-01-08
#
#   Marketing_Airline_Network  DOT_ID_Marketing_Airline  \
# 0                        DL                     19790
# 1                        DL                     19790
# 2                        DL                     19790
# 3                        DL                     19790
# 4                        DL                     19790
#
#   IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  ... Distance  \
# 0                          DL                             4628  ...    752.0
# 1                          DL                             4628  ...    752.0
# 2                          DL                             4628  ...    752.0
# 3                          DL                             4628  ...    752.0
# 4                          DL                             4628  ...    752.0
#
#    Distance_Group Carrier_Delay Weather_Delay  NAS_Delay  Security_Delay  \
# 0               4           NaN           NaN        NaN             NaN
# 1               4           NaN           NaN        NaN             NaN
# 2               4           NaN           NaN        NaN             NaN
# 3               4           NaN           NaN        NaN             NaN
# 4               4           NaN           NaN        NaN             NaN
#
#    Late_Aircraft_Delay  Duplicate Missing_Due_To_Cancellation  \
# 0                  NaN          N                       False
# 1                  NaN          N                       False
# 2                  NaN          N                       False
# 3                  NaN          N                       False
# 4                  NaN          N                       False
#
#              Airline
# 0  Endeavor Air Inc.
# 1  Endeavor Air Inc.
# 2  Endeavor Air Inc.
# 3  Endeavor Air Inc.
# 4  Endeavor Air Inc.
#
# [5 rows x 66 columns]

# %%
df.tail()
# Out:
#          Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 6311866  2021        4     12            12            7  2021-12-12
# 6311867  2021        4     12            12            7  2021-12-12
# 6311868  2021        4     12            12            7  2021-12-12
# 6311869  2021        4     12            12            7  2021-12-12
# 6311870  2021        4     12            12            7  2021-12-12
#
#         Marketing_Airline_Network  DOT_ID_Marketing_Airline  \
# 6311866                        UA                     19977
# 6311867                        UA                     19977
# 6311868                        UA                     19977
# 6311869                        UA                     19977
# 6311870                        UA                     19977
#
#         IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  ...  \
# 6311866                          UA                             4174  ...
# 6311867                          UA                             4173  ...
# 6311868                          UA                             4171  ...
# 6311869                          UA                             4169  ...
# 6311870                          UA                             4166  ...
#
#         Distance  Distance_Group Carrier_Delay Weather_Delay  NAS_Delay  \
# 6311866    266.0               2           NaN           NaN        NaN
# 6311867    277.0               2           NaN           NaN        NaN
# 6311868    199.0               1           NaN           NaN        NaN
# 6311869    199.0               1           NaN           NaN        NaN
# 6311870    277.0               2           NaN           NaN        NaN
#
#          Security_Delay  Late_Aircraft_Delay  Duplicate  \
# 6311866             NaN                  NaN          N
# 6311867             NaN                  NaN          N
# 6311868             NaN                  NaN          N
# 6311869             NaN                  NaN          N
# 6311870             NaN                  NaN          N
#
#         Missing_Due_To_Cancellation                                   Airline
# 6311866                       False  GoJet Airlines, LLC d/b/a United Express
# 6311867                       False  GoJet Airlines, LLC d/b/a United Express
# 6311868                       False  GoJet Airlines, LLC d/b/a United Express
# 6311869                       False  GoJet Airlines, LLC d/b/a United Express
# 6311870                       False  GoJet Airlines, LLC d/b/a United Express
#
# [5 rows x 66 columns]

# %%
# Display the column names to verify

print("DF DataFrame Columns:", df.columns)
# Out:
# DF DataFrame Columns: Index(['Year', 'Quarter', 'Month', 'Day_of_Month', 'Day_of_Week',
#        'Flight_Date', 'Marketing_Airline_Network', 'DOT_ID_Marketing_Airline',
#        'IATA_Code_Marketing_Airline', 'Flight_Number_Marketing_Airline',
#        'Operating_Airline', 'DOT_ID_Operating_Airline',
#        'IATA_Code_Operating_Airline', 'Tail_Number',
#        'Flight_Number_Operating_Airline', 'Origin_Airport_ID',
#        'Origin_Airport_Seq_ID', 'Origin_City_Market_ID', 'Origin',
#        'Origin_City_Name', 'Origin_State', 'Origin_State_Fips',
#        'Origin_State_Name', 'Dest_Airport_ID', 'Dest_Airport_Seq_ID',
#        'Dest_City_Market_ID', 'Dest', 'Dest_City_Name', 'Dest_State',
#        'Dest_State_Fips', 'Dest_State_Name', 'CRS_Dep_Time', 'Dep_Time',
#        'Dep_Delay', 'Dep_Delay_Minutes', 'Dep_Del_15',
#        'Departure_Delay_Groups', 'Dep_Time_Blk', 'Taxi_Out', 'Wheels_Off',
#        'Wheels_On', 'Taxi_In', 'CRS_Arr_Time', 'Arr_Time', 'Arr_Delay',
#        'Arr_Delay_Minutes', 'Arr_Del_15', 'Arrival_Delay_Groups',
#        'Arr_Time_Blk', 'Cancelled', 'Cancellation_Code', 'Diverted',
#        'CRS_Elapsed_Time', 'Actual_Elapsed_Time', 'Air_Time', 'Flights',
#        'Distance', 'Distance_Group', 'Carrier_Delay', 'Weather_Delay',
#        'NAS_Delay', 'Security_Delay', 'Late_Aircraft_Delay', 'Duplicate',
#        'Missing_Due_To_Cancellation', 'Airline'],
#       dtype='object')

# %% [markdown]
# ## 2. General Statistics

# %%
df.describe()
# Out:
#             Year       Quarter         Month  Day_of_Month   Day_of_Week  \
# count  6311871.0  6.311871e+06  6.311871e+06  6.311871e+06  6.311871e+06
# mean      2021.0  2.650051e+00  6.969905e+00  1.579259e+01  4.013676e+00
# std          0.0  1.077919e+00  3.300914e+00  8.786535e+00  2.006264e+00
# min       2021.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2021.0  2.000000e+00  4.000000e+00  8.000000e+00  2.000000e+00
# 50%       2021.0  3.000000e+00  7.000000e+00  1.600000e+01  4.000000e+00
# 75%       2021.0  4.000000e+00  1.000000e+01  2.300000e+01  6.000000e+00
# max       2021.0  4.000000e+00  1.200000e+01  3.100000e+01  7.000000e+00
#
#        DOT_ID_Marketing_Airline  Flight_Number_Marketing_Airline  \
# count              6.311871e+06                     6.311871e+06
# mean               1.983155e+04                     2.795597e+03
# std                2.681009e+02                     1.827375e+03
# min                1.939300e+04                     1.000000e+00
# 25%                1.979000e+04                     1.195000e+03
# 50%                1.980500e+04                     2.449000e+03
# 75%                1.997700e+04                     4.444000e+03
# max                2.043600e+04                     9.695000e+03
#
#        DOT_ID_Operating_Airline  Flight_Number_Operating_Airline  \
# count              6.311871e+06                     6.311871e+06
# mean               2.001237e+04                     2.795586e+03
# std                3.773422e+02                     1.827373e+03
# min                1.939300e+04                     1.000000e+00
# 25%                1.979000e+04                     1.195000e+03
# 50%                1.997700e+04                     2.449000e+03
# 75%                2.039700e+04                     4.444000e+03
# max                2.050000e+04                     9.695000e+03
#
#        Origin_Airport_ID  ...  Actual_Elapsed_Time      Air_Time    Flights  \
# count       6.311871e+06  ...         6.185870e+06  6.185870e+06  6311871.0
# mean        1.265833e+04  ...         1.344372e+02  1.105702e+02        1.0
# std         1.532783e+03  ...         7.023792e+01  6.888632e+01        0.0
# min         1.013500e+04  ...         1.400000e+01  8.000000e+00        1.0
# 25%         1.129200e+04  ...         8.300000e+01  6.000000e+01        1.0
# 50%         1.288900e+04  ...         1.180000e+02  9.400000e+01        1.0
# 75%         1.405700e+04  ...         1.650000e+02  1.400000e+02        1.0
# max         1.686900e+04  ...         7.940000e+02  7.110000e+02        1.0
#
#            Distance  Distance_Group  Carrier_Delay  Weather_Delay  \
# count  6.311871e+06    6.311871e+06   1.068058e+06   1.068058e+06
# mean   7.955762e+02    3.653994e+00   2.682974e+01   4.612398e+00
# std    5.832931e+02    2.281563e+00   7.407939e+01   3.533947e+01
# min    3.100000e+01    1.000000e+00   0.000000e+00   0.000000e+00
# 25%    3.700000e+02    2.000000e+00   0.000000e+00   0.000000e+00
# 50%    6.460000e+02    3.000000e+00   6.000000e+00   0.000000e+00
# 75%    1.033000e+03    5.000000e+00   2.600000e+01   0.000000e+00
# max    5.812000e+03    1.100000e+01   3.089000e+03   1.740000e+03
#
#           NAS_Delay  Security_Delay  Late_Aircraft_Delay
# count  1.068058e+06    1.068058e+06         1.068058e+06
# mean   1.124908e+01    2.132581e-01         2.401460e+01
# std    2.915515e+01    4.236554e+00         5.574851e+01
# min    0.000000e+00    0.000000e+00         0.000000e+00
# 25%    0.000000e+00    0.000000e+00         0.000000e+00
# 50%    0.000000e+00    0.000000e+00         0.000000e+00
# 75%    1.500000e+01    0.000000e+00         2.700000e+01
# max    1.642000e+03    9.830000e+02         2.093000e+03
#
# [8 rows x 46 columns]

# %%
# Calculate general statistics for delays and cancellations
delay_stats = df[['Dep_Delay', 'Arr_Delay', 'Cancelled', 'Diverted']].describe()
print(delay_stats)
# Out:
#           Dep_Delay     Arr_Delay     Cancelled      Diverted
# count  6.203458e+06  6.185870e+06  6.311871e+06  6.311871e+06
# mean   9.468347e+00  3.290244e+00  1.758876e-02  2.373623e-03
# std    4.837844e+01  5.012311e+01  1.314511e-01  4.866199e-02
# min   -1.050000e+02 -1.070000e+02  0.000000e+00  0.000000e+00
# 25%   -6.000000e+00 -1.600000e+01  0.000000e+00  0.000000e+00
# 50%   -2.000000e+00 -7.000000e+00  0.000000e+00  0.000000e+00
# 75%    6.000000e+00  6.000000e+00  0.000000e+00  0.000000e+00
# max    3.095000e+03  3.089000e+03  1.000000e+00  1.000000e+00

# %%
# Identify the most common delay reasons and cancellation codes
common_delays = df[['Carrier_Delay', 'Weather_Delay', 'NAS_Delay', 'Security_Delay', 'Late_Aircraft_Delay']].sum()
print(common_delays)
# Out:
# Carrier_Delay          28655723.0
# Weather_Delay           4926309.0
# NAS_Delay              12014666.0
# Security_Delay           227772.0
# Late_Aircraft_Delay    25648990.0
# dtype: float64

# %%
common_cancellation_codes = df['Cancellation_Code'].value_counts()
print(common_cancellation_codes)
# Out:
# Cancellation_Code
# B    58774
# A    42448
# C     8609
# D     1187
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Temporal Analysis

# %%
# Analyze delays and cancellations by day of the week

delays_by_day = df.groupby('Day_of_Week')[['Dep_Delay', 'Arr_Delay']].mean()
print(delays_by_day)
# Out:
#              Dep_Delay  Arr_Delay
# Day_of_Week
# 1            10.781977   4.751409
# 2             7.696805   1.099441
# 3             7.333399   1.105711
# 4             9.656072   4.024692
# 5             9.864492   3.970060
# 6             9.619819   2.882691
# 7            10.987860   4.746381

# %%
cancellations_by_day = df.groupby('Day_of_Week')['Cancelled'].sum()
print(cancellations_by_day)
# Out:
# Day_of_Week
# 1    21036.0
# 2    14300.0
# 3    12925.0
# 4    15595.0
# 5    14066.0
# 6    12871.0
# 7    20225.0
# Name: Cancelled, dtype: float64

# %%
# Analyze delays and cancellations by month
delays_by_month = df.groupby('Month')[['Dep_Delay', 'Arr_Delay']].mean()
print(delays_by_month)
# Out:
#        Dep_Delay  Arr_Delay
# Month
# 1       1.960001  -5.222584
# 2       5.391787  -0.007875
# 3       3.017692  -4.424335
# 4       3.922702  -3.755068
# 5       6.602499  -0.258733
# 6      15.903085  10.827168
# 7      16.969971  12.124516
# 8      14.565820   9.847785
# 9       6.732790   0.642644
# 10     10.293038   4.217348
# 11      7.538774   0.582691
# 12     13.338059   6.872567

# %%
cancellations_by_month = df.groupby('Month')['Cancelled'].sum()
print(cancellations_by_month)
# Out:
# Month
# 1      4155.0
# 2     20201.0
# 3      5904.0
# 4      2561.0
# 5      2350.0
# 6      9196.0
# 7     10195.0
# 8     18734.0
# 9      7776.0
# 10    12614.0
# 11     3559.0
# 12    13773.0
# Name: Cancelled, dtype: float64

# %%
# Analyze delays and cancellations by quarter

delays_by_quarter = df.groupby('Quarter')[['Dep_Delay', 'Arr_Delay']].mean()
print(delays_by_quarter)
# Out:
#          Dep_Delay  Arr_Delay
# Quarter
# 1         3.349222  -3.432157
# 2         9.169927   2.704667
# 3        12.898932   7.694826
# 4        10.378297   3.879867

# %%
cancellations_by_quarter = df.groupby('Quarter')['Cancelled'].sum()
print(cancellations_by_quarter)
# Out:
# Quarter
# 1    30260.0
# 2    14107.0
# 3    36705.0
# 4    29946.0
# Name: Cancelled, dtype: float64

# %% [markdown]
# ## 4. Geospatial Analysis

# %%
# Determine the origin and destination airports with the highest delays and cancellations

origin_delays = df.groupby('Origin_City_Name')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Dep_Delay', ascending=False)
print(origin_delays.head(10))
# Out:
#                        Dep_Delay   Arr_Delay
# Origin_City_Name
# Pago Pago, TT         238.000000  236.000000
# Bishop, CA             62.971429   52.485714
# Hyannis, MA            28.807018   19.280702
# Cody, WY               27.128655   25.845250
# West Yellowstone, MT   24.798319   18.800425
# Devils Lake, ND        24.600321   20.123577
# Columbia, MO           24.401754   18.897767
# Dickinson, ND          24.172676   23.102662
# Gunnison, CO           23.727778   22.985410
# Ogdensburg, NY         23.649007   15.744610

# %%
destination_delays = df.groupby('Dest_City_Name')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Arr_Delay', ascending=False)
print(destination_delays.head(10))
# Out:
#                           Dep_Delay  Arr_Delay
# Dest_City_Name
# Pago Pago, TT             51.166667  54.833333
# Dickinson, ND             47.839015  44.211538
# Presque Isle/Houlton, ME  33.871456  29.998092
# Bishop, CA                33.057143  26.542857
# Gunnison, CO              32.223947  26.165354
# Cody, WY                  21.036204  21.179283
# Aguadilla, PR             23.132863  20.075533
# Aspen, CO                 21.304887  19.837723
# Punta Gorda, FL           17.174367  19.049768
# Williston, ND             24.884686  18.793103

# %%
# Identify the airlines with the highest delays and cancellations
airline_delays = df.groupby('Airline')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Dep_Delay', ascending=False)
print(airline_delays)
# Out:
#                                            Dep_Delay  Arr_Delay
# Airline
# Commutair Aka Champlain Enterprises, Inc.  17.817486  16.065893
# JetBlue Airways                            16.584312  10.610668
# Allegiant Air                              15.222554  15.286265
# Mesa Airlines Inc.                         14.742579   8.974378
# Southwest Airlines Co.                     13.334240   5.501017
# Frontier Airlines Inc.                     11.490848   6.523572
# Spirit Air Lines                           11.451355   6.646201
# American Airlines Inc.                     11.408765   3.067912
# Air Wisconsin Airlines Corp                11.335232   7.345609
# GoJet Airlines, LLC d/b/a United Express   11.131844   7.009641
# SkyWest Airlines Inc.                      10.056802   4.737164
# United Air Lines Inc.                       8.995028   3.405323
# Envoy Air                                   6.370959   1.421341
# Delta Air Lines Inc.                        5.939530  -1.533494
# Comair Inc.                                 5.727404   1.045623
# Republic Airlines                           5.188196  -0.361953
# Capital Cargo International                 4.526329  -0.128105
# Alaska Airlines Inc.                        3.855417   0.500561
# Horizon Air                                 3.646293   0.514759
# Endeavor Air Inc.                           2.785414  -5.365965
# Empire Airlines Inc.                        1.848214  -0.044643
# Hawaiian Airlines Inc.                      1.788135  -1.228912

# %%
airline_cancellations = df.groupby('Airline')['Cancelled'].sum().sort_values(ascending=False)
print(airline_cancellations)
# Out:
# Airline
# Southwest Airlines Co.                       23505.0
# American Airlines Inc.                       16478.0
# SkyWest Airlines Inc.                        13323.0
# United Air Lines Inc.                         6107.0
# Envoy Air                                     5686.0
# Spirit Air Lines                              5661.0
# Republic Airlines                             5647.0
# Mesa Airlines Inc.                            4763.0
# Allegiant Air                                 3829.0
# Delta Air Lines Inc.                          3631.0
# JetBlue Airways                               3299.0
# Alaska Airlines Inc.                          3217.0
# Commutair Aka Champlain Enterprises, Inc.     2489.0
# Air Wisconsin Airlines Corp                   2409.0
# Comair Inc.                                   2254.0
# GoJet Airlines, LLC d/b/a United Express      2134.0
# Horizon Air                                   2096.0
# Frontier Airlines Inc.                        1929.0
# Capital Cargo International                   1323.0
# Endeavor Air Inc.                              974.0
# Hawaiian Airlines Inc.                         264.0
# Empire Airlines Inc.                             0.0
# Name: Cancelled, dtype: float64

# %% [markdown]
# ## 5. Tail Number Analysis

# %%
# Check if specific aircraft tail numbers are more prone to delays or cancellations
tail_number_delays = df.groupby('Tail_Number')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Dep_Delay', ascending=False)
print(tail_number_delays.head(10))
# Out:
#               Dep_Delay  Arr_Delay
# Tail_Number
# N567NK       655.000000        NaN
# N360NK       223.000000        NaN
# N506DN        53.777778  48.555556
# N512MJ        49.246154  53.265625
# N838UA        48.043478  43.695652
# N507DN        44.857143  41.000000
# N59053        44.641975  37.975000
# N676UA        42.774194  35.108696
# N761AJ        41.588933  33.746032
# N756AM        39.986971  30.804560

# %%
tail_number_cancellations = df.groupby('Tail_Number')['Cancelled'].sum().sort_values(ascending=False)
print(tail_number_cancellations.head(10))
# Out:
# Tail_Number
# Unknown    23303.0
# N606AE        89.0
# N631RW        84.0
# N637RW        72.0
# N698CB        71.0
# N668HH        69.0
# N726YX        69.0
# N612AE        67.0
# N889AS        66.0
# N627QX        65.0
# Name: Cancelled, dtype: float64

# %% [markdown]
# ## 6. Aggregation and Grouping (Wrangling)

# %%
# Group by various metrics to gain insights
grouped_by_airline = df.groupby('Airline').agg({
    'Dep_Delay': 'mean',
    'Arr_Delay': 'mean',
    'Cancelled': 'sum'
}).sort_values(by='Dep_Delay', ascending=False)
print(grouped_by_airline)
# Out:
#                                            Dep_Delay  Arr_Delay  Cancelled
# Airline
# Commutair Aka Champlain Enterprises, Inc.  17.817486  16.065893     2489.0
# JetBlue Airways                            16.584312  10.610668     3299.0
# Allegiant Air                              15.222554  15.286265     3829.0
# Mesa Airlines Inc.                         14.742579   8.974378     4763.0
# Southwest Airlines Co.                     13.334240   5.501017    23505.0
# Frontier Airlines Inc.                     11.490848   6.523572     1929.0
# Spirit Air Lines                           11.451355   6.646201     5661.0
# American Airlines Inc.                     11.408765   3.067912    16478.0
# Air Wisconsin Airlines Corp                11.335232   7.345609     2409.0
# GoJet Airlines, LLC d/b/a United Express   11.131844   7.009641     2134.0
# SkyWest Airlines Inc.                      10.056802   4.737164    13323.0
# United Air Lines Inc.                       8.995028   3.405323     6107.0
# Envoy Air                                   6.370959   1.421341     5686.0
# Delta Air Lines Inc.                        5.939530  -1.533494     3631.0
# Comair Inc.                                 5.727404   1.045623     2254.0
# Republic Airlines                           5.188196  -0.361953     5647.0
# Capital Cargo International                 4.526329  -0.128105     1323.0
# Alaska Airlines Inc.                        3.855417   0.500561     3217.0
# Horizon Air                                 3.646293   0.514759     2096.0
# Endeavor Air Inc.                           2.785414  -5.365965      974.0
# Empire Airlines Inc.                        1.848214  -0.044643        0.0
# Hawaiian Airlines Inc.                      1.788135  -1.228912      264.0

# %%
grouped_by_airport = df.groupby('Origin_City_Name').agg({
    'Dep_Delay': 'mean',
    'Arr_Delay': 'mean',
    'Cancelled': 'sum'
}).sort_values(by='Dep_Delay', ascending=False)
print(grouped_by_airport)
# Out:
#                        Dep_Delay   Arr_Delay  Cancelled
# Origin_City_Name
# Pago Pago, TT         238.000000  236.000000        0.0
# Bishop, CA             62.971429   52.485714        4.0
# Hyannis, MA            28.807018   19.280702        4.0
# Cody, WY               27.128655   25.845250       22.0
# West Yellowstone, MT   24.798319   18.800425        3.0
# ...                          ...         ...        ...
# Dubuque, IA            -3.549195  -12.366726       13.0
# Saipan, TT             -4.613383   -3.914498        0.0
# Gustavus, AK           -5.551724   -2.804598        2.0
# Nome, AK               -6.496479   -4.297872       16.0
# Deadhorse, AK         -13.259594  -12.148984        7.0
#
# [374 rows x 3 columns]

# %%
# Import Seaborn for Visualizations

import seaborn as sns

# %%
# Ensure that Flight Date is in datetime format

df['Flight_Date'] = pd.to_datetime(df['Flight_Date'])
df_2021 = df[df['Flight_Date'].dt.year == 2021]

# %%
# Set save path for saving visuals

save_path = os.path.join(path, '03 - Visuals')

# %%
# Delays by Day of the Week
delays_by_day = df_2021.groupby('Day_of_Week')[['Dep_Delay', 'Arr_Delay']].mean()
delays_by_day.plot(kind='bar', figsize=(10, 6), title='2021 Average Delays by Day of the Week')
plt.ylabel('Average Delay (minutes)')
plt.savefig(f'{save_path}delays_by_day_of_week_2021.png')
plt.show()

# %%
delays_by_quarter = df_2021.groupby('Quarter')[['Dep_Delay', 'Arr_Delay']].mean()

# %%
# Plot the delays by quarter
delays_by_quarter.plot(kind='bar', figsize=(10, 6), title='2021 Average Delays by Quarter')
plt.ylabel('Average Delay (minutes)')
plt.xlabel('Quarter')
plt.tight_layout()  # Adjust layout to prevent clipping
plt.savefig(f'{save_path}delays_by_quarter_2021.png')
plt.show()

# %%
# Cancellations by Day of the Week
cancellations_by_day = df_2021.groupby('Day_of_Week')['Cancelled'].sum()
ax = cancellations_by_day.plot(kind='bar', figsize=(10, 6), title='2021 Cancellations by Day of the Week', color='red')
plt.ylabel('Number of Cancellations')
plt.savefig(f'{save_path}cancellations_by_day_of_week_2021.png')
plt.show()

# %%
# Monthly Trends
delays_by_month = df_2021.groupby('Month')[['Dep_Delay', 'Arr_Delay']].mean()
ax = delays_by_month.plot(kind='line', figsize=(10, 6), title='2021 Average Delays by Month')
plt.ylabel('Average Delay (minutes)')
plt.savefig(f'{save_path}delays_by_month_2021.png')
plt.show()

# %%
# Monthly Cancellation Trends
cancellations_by_month = df_2021.groupby('Month')[['Cancelled']].sum()
ax = cancellations_by_month.plot(kind='line', figsize=(10, 6), title='2021 Cancellations by Month')
plt.ylabel('Number of Cancellations')
plt.savefig(f'{save_path}cancellations_by_month_2021.png')
plt.show()

# %%
# Dictionary mapping abbreviations to full names
airline_mapping = {
    'AA': 'American Airlines Inc.',
    'AS': 'Alaska Airlines Inc.',
    'B6': 'JetBlue Airways',
    'DL': 'Delta Air Lines Inc.',
    'F9': 'Frontier Airlines Inc.',
    'G4': 'Allegiant Air',
    'HA': 'Hawaiian Airlines Inc.',
    'NK': 'Spirit Air Lines',
    'UA': 'United Airlines Inc.',
    'VX': 'Virgin America',
    'WN': 'Southwest Airlines Co.'
}

# %%
# Add a new column with full names
df_2021['Marketing_Airline_Network_Full'] = df_2021['Marketing_Airline_Network'].map(airline_mapping)

# %%
# Rename columns
df_2021 = df_2021.rename(columns={
    'Marketing_Airline_Network': 'Marketing_Airline_Network_Code',
    'Marketing_Airline_Network_Full': 'Marketing_Airline_Network'
})

# %%
# Distribution of Delays by Marketing Airline Network
plt.figure(figsize=(16, 10))  # Increase the width and height of the figure
sns.boxplot(x='Marketing_Airline_Network', y='Dep_Delay', data=df_2021)
plt.title('2021 Distribution of Departure Delays by Marketing Airline Network', fontsize=16)
plt.ylabel('Departure Delay (minutes)', fontsize=14)
plt.xlabel('Marketing Airline Network', fontsize=14)
plt.xticks(rotation=45, fontsize=10)  # Rotate labels and adjust font size
plt.tight_layout()  # Adjust layout to prevent clipping
plt.savefig(f'{save_path}delays_by_airline_network_boxplot_2021.png')
plt.show()

# %% [markdown]
# ## I will be using Tableau for further Geospatial Analsysis.

# %%
# Count the number of flights per month using the existing 'Month' column
flights_per_month = df_2021['Month'].value_counts().sort_index()

# %%
# Plot the line chart

ax = flights_per_month.plot(kind='line', figsize=(10, 6), title='2021 Flights per Month')
plt.ylabel('Number of Flights')
plt.savefig(f'{save_path}flights_per_month_2021.png')
plt.show()

# %%
# Save 2021 flights dataframe, now with Marketing_Airline_Network & Marketing_Airline_Network_Code columns

df_2021.to_csv(os.path.join(path, 'flights2021.csv'))
