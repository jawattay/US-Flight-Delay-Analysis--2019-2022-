# %%
#import libraries and data

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
path = r'C:\Users\Josh Wattay\anaconda3\Flight Delay Analysis'

# %%
#import data

flights2022 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Combined_Flights_2022.csv'))

# %%
#check output 

flights2022.head()
# Out:
#    FlightDate                                    Airline Origin Dest  \
# 0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# 0      False     False        1133   1123.0              0.0     -10.0  ...
# 1      False     False         732    728.0              0.0      -4.0  ...
# 2      False     False        1529   1514.0              0.0     -15.0  ...
# 3      False     False        1435   1430.0              0.0      -5.0  ...
# 4      False     False        1135   1135.0              0.0       0.0  ...
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# ...

# %%
#create samples due to high volume of records
#will be using 100k records per year for 2018, 2019, 2020, 2021, and 2022

sample18 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Combined_Flights_2018.csv')).sample(100000, random_state = 11)

# %%
#check output and shape of sample

sample18.head()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 2079139  2018-12-02             Comair Inc.    DCA  BTV      False     False
# 4054924  2018-06-30        Spirit Air Lines    ATL  LAS      False     False
# 2486050  2018-02-11  Frontier Airlines Inc.    MCI  RSW      False     False
# 4020576  2018-06-22   United Air Lines Inc.    DEN  CID      False     False
# 715981   2018-10-19   SkyWest Airlines Inc.    BGM  DTW      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 2079139        1459   1533.0             34.0      34.0  ...     1554.0
# 4054924        1810   1833.0             23.0      23.0  ...     1850.0
# 2486050        1234   1241.0              7.0       7.0  ...     1249.0
# 4020576        2017   2156.0             99.0      99.0  ...     2211.0
# 715981         1728   1725.0              0.0      -3.0  ...     1733.0
#
# ...

# %%
sample18.tail()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 1754446  2018-11-09             Horizon Air    BZN  PDX      False     False
# 4791052  2018-08-19  American Airlines Inc.    CLT  SAT      False     False
# 1531238  2018-11-06  Southwest Airlines Co.    MDW  BDL      False     False
# 1842350  2018-12-25   SkyWest Airlines Inc.    MSP  SFO      False     False
# 2790780  2018-03-02  Southwest Airlines Co.    MDW  MCO      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 1754446        1603   1606.0              3.0       3.0  ...     1614.0
# 4791052        1615   1658.0             43.0      43.0  ...     1715.0
# 1531238        2155   2151.0              0.0      -4.0  ...     2205.0
# 1842350        1805   1802.0              0.0      -3.0  ...     1817.0
# 2790780        1000    958.0              0.0      -2.0  ...     1007.0
#
# ...

# %%
sample18.shape
# Out:
# (100000, 61)

# %%
#create sample for 2019

sample19 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Combined_Flights_2019.csv')).sample(100000, random_state = 11)

# %%
#check output and shape of sample

sample19.head()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 4706373  2019-07-27        Spirit Air Lines    SEA  LAS      False     False
# 1094369  2019-02-25  American Airlines Inc.    LAX  BNA      False     False
# 1663959  2019-08-20  Southwest Airlines Co.    ATL  MSY      False     False
# 1459243  2019-08-13    Delta Air Lines Inc.    LGA  MSY      False     False
# 340728   2019-04-11             Comair Inc.    CLT  ILM      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 4706373         720    716.0              0.0      -4.0  ...      730.0
# 1094369         930    928.0              0.0      -2.0  ...      937.0
# 1663959         700    655.0              0.0      -5.0  ...      707.0
# 1459243        1329   1327.0              0.0      -2.0  ...     1337.0
# 340728         2009   2019.0             10.0      10.0  ...     2030.0
#
# ...

# %%
sample19.tail()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 8011367  2019-01-15    Delta Air Lines Inc.    ATL  DCA      False     False
# 5660652  2019-05-27  American Airlines Inc.    ELP  DFW      False     False
# 1399823  2019-08-13  Southwest Airlines Co.    OKC  DAL      False     False
# 1224506  2019-02-21  Southwest Airlines Co.    DEN  PHL      False     False
# 2502307  2019-06-20   United Air Lines Inc.    LAX  EWR      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 8011367        2109   2108.0              0.0      -1.0  ...     2122.0
# 5660652        1058   1046.0              0.0     -12.0  ...     1059.0
# 1399823        1805   1811.0              6.0       6.0  ...     1821.0
# 1224506        1050   1059.0              9.0       9.0  ...     1116.0
# 2502307         815    815.0              0.0       0.0  ...      837.0
#
# ...

# %%
sample19.shape
# Out:
# (100000, 61)

# %%
#create sample for 2020

sample20 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Combined_Flights_2020.csv')).sample(100000, random_state = 11)

# %%
#check sample output and shape

sample20.head()
# Out:
#          FlightDate                      Airline Origin Dest  Cancelled  \
# 3862647  2020-02-18  Capital Cargo International    CLT  TRI      False
# 2654512  2020-01-25         Alaska Airlines Inc.    LAS  SFO      False
# 2020174  2020-10-14        SkyWest Airlines Inc.    MSP  IMT      False
# 972377   2020-03-31        SkyWest Airlines Inc.    FLG  PHX      False
# 2558117  2020-07-19        United Air Lines Inc.    LAX  ORD      False
#
#          Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# 3862647     False         920    911.0              0.0      -9.0  ...
# 2654512     False         615    604.0              0.0     -11.0  ...
# 2020174     False        1511   1509.0              0.0      -2.0  ...
# 972377      False        1517   1507.0              0.0     -10.0  ...
# 2558117     False        2359   2348.0              0.0     -11.0  ...
#
#          WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# ...

# %%
sample20.tail()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 1266856  2020-03-19               Envoy Air    COS  DFW      False     False
# 168897   2020-09-18  American Airlines Inc.    TPA  DFW      False     False
# 1563959  2020-12-04  Frontier Airlines Inc.    MCO  BWI      False     False
# 2272254  2020-07-17      Mesa Airlines Inc.    DFW  BMI      False     False
# 4710495  2020-04-02        Spirit Air Lines    TPA  CAK      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 1266856        1216   1213.0              0.0      -3.0  ...     1331.0
# 168897         1404   1359.0              0.0      -5.0  ...     1410.0
# 1563959         600    555.0              0.0      -5.0  ...      610.0
# 2272254        1850   1840.0              0.0     -10.0  ...     1905.0
# 4710495        1605   1626.0             21.0      21.0  ...     1638.0
#
# ...

# %%
sample20.shape
# Out:
# (100000, 61)

# %%
#create sample for 2021

sample21 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Combined_Flights_2021.csv')).sample(100000, random_state = 11)

# %%
#check sample output and shape

sample21.head()
# Out:
#          FlightDate                      Airline Origin Dest  Cancelled  \
# 3800526  2021-07-22            Republic Airlines    SDF  DTW      False
# 6157463  2021-06-20              JetBlue Airways    JAX  BOS      False
# 4462349  2021-05-23       American Airlines Inc.    DFW  BOS      False
# 2163394  2021-09-16       Frontier Airlines Inc.    CVG  MCO      False
# 4494348  2021-05-01  Capital Cargo International    ROA  CLT      False
#
#          Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# 3800526     False        1820   1813.0              0.0      -7.0  ...
# 6157463     False         935    933.0              0.0      -2.0  ...
# 4462349     False        1100   1059.0              0.0      -1.0  ...
# 2163394     False         839    827.0              0.0     -12.0  ...
# 4494348     False         700   1200.0            300.0     300.0  ...
#
#          WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# ...

# %%
sample21.tail()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 2332722  2021-09-24   United Air Lines Inc.    PHL  ORD      False     False
# 4457302  2021-05-13  American Airlines Inc.    COS  DFW      False     False
# 4681556  2021-05-08   SkyWest Airlines Inc.    BTR  DFW      False     False
# 127784   2021-03-05  Southwest Airlines Co.    OAK  PSP      False     False
# 5839030  2021-06-20      Mesa Airlines Inc.    STL  IAH      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 2332722         830    841.0             11.0      11.0  ...      858.0
# 4457302        1235   1240.0              5.0       5.0  ...     1254.0
# 4681556         600    554.0              0.0      -6.0  ...      605.0
# 127784          905    901.0              0.0      -4.0  ...      912.0
# 5839030         600    551.0              0.0      -9.0  ...      605.0
#
# ...

# %%
sample21.shape
# Out:
# (100000, 61)

# %%
#create sample for 2022

sample22 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Combined_Flights_2022.csv')).sample(100000, random_state = 11)

# %%
#check sample output and shape

sample22.head()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 2845243  2022-06-07  American Airlines Inc.    DCA  LGA      False     False
# 2716940  2022-06-08  Southwest Airlines Co.    MCO  SJU      False     False
# 133831   2022-04-19       Republic Airlines    LGA  CMH      False     False
# 2985881  2022-01-27    Delta Air Lines Inc.    SLC  FCA      False     False
# 2483165  2022-06-21    Delta Air Lines Inc.    LGA  PBI      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 2845243        1300   1253.0              0.0      -7.0  ...     1320.0
# 2716940        1400   1417.0             17.0      17.0  ...     1450.0
# 133831          930    922.0              0.0      -8.0  ...      946.0
# 2985881        2240   2237.0              0.0      -3.0  ...     2252.0
# 2483165         705    703.0              0.0      -2.0  ...      801.0
#
# ...

# %%
sample22.tail()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 4016104  2022-03-08  Southwest Airlines Co.    DSM  DEN      False     False
# 3347015  2022-01-16       Republic Airlines    DCA  ATL      False     False
# 640944   2022-02-03  Southwest Airlines Co.    DEN  ORF      False     False
# 3329891  2022-01-09         JetBlue Airways    MCO  PSE      False     False
# 2702925  2022-06-22  Southwest Airlines Co.    DEN  SAT      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 4016104        1750   1751.0              1.0       1.0  ...     1803.0
# 3347015         831    826.0              0.0      -5.0  ...      856.0
# 640944         1810   1826.0             16.0      16.0  ...     1836.0
# 3329891         600    557.0              0.0      -3.0  ...      615.0
# 2702925        1155   1152.0              0.0      -3.0  ...     1206.0
#
# ...

# %%
sample22.shape
# Out:
# (100000, 61)

# %%
#export samples as .csv files and prepare to concatinate

sample18.to_csv(os.path.join(path, '02 Data', 'Original Data', 'Sample_Flights_2018.csv'), index=False)  

# Specify index=False to avoid writing row numbers as a column

# %%
sample19.to_csv(os.path.join(path, '02 Data', 'Original Data', 'Sample_Flights_2019.csv'), index=False)

# %%
sample20.to_csv(os.path.join(path, '02 Data', 'Original Data', 'Sample_Flights_2020.csv'), index=False)

# %%
sample21.to_csv(os.path.join(path, '02 Data', 'Original Data', 'Sample_Flights_2021.csv'), index=False)

# %%
sample22.to_csv(os.path.join(path, '02 Data', 'Original Data', 'Sample_Flights_2022.csv'), index=False)

# %%
#concatinate samples to combine data for future analysis and data cleaning

samples_combined = pd.concat([sample18, sample19, sample20, sample21, sample22], axis=0)

# %%
#check output and shape

samples_combined.head()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 2079139  2018-12-02             Comair Inc.    DCA  BTV      False     False
# 4054924  2018-06-30        Spirit Air Lines    ATL  LAS      False     False
# 2486050  2018-02-11  Frontier Airlines Inc.    MCI  RSW      False     False
# 4020576  2018-06-22   United Air Lines Inc.    DEN  CID      False     False
# 715981   2018-10-19   SkyWest Airlines Inc.    BGM  DTW      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 2079139        1459   1533.0             34.0      34.0  ...     1554.0
# 4054924        1810   1833.0             23.0      23.0  ...     1850.0
# 2486050        1234   1241.0              7.0       7.0  ...     1249.0
# 4020576        2017   2156.0             99.0      99.0  ...     2211.0
# 715981         1728   1725.0              0.0      -3.0  ...     1733.0
#
# ...

# %%
samples_combined.tail()
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 4016104  2022-03-08  Southwest Airlines Co.    DSM  DEN      False     False
# 3347015  2022-01-16       Republic Airlines    DCA  ATL      False     False
# 640944   2022-02-03  Southwest Airlines Co.    DEN  ORF      False     False
# 3329891  2022-01-09         JetBlue Airways    MCO  PSE      False     False
# 2702925  2022-06-22  Southwest Airlines Co.    DEN  SAT      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 4016104        1750   1751.0              1.0       1.0  ...     1803.0
# 3347015         831    826.0              0.0      -5.0  ...      856.0
# 640944         1810   1826.0             16.0      16.0  ...     1836.0
# 3329891         600    557.0              0.0      -3.0  ...      615.0
# 2702925        1155   1152.0              0.0      -3.0  ...     1206.0
#
# ...

# %%
samples_combined.shape
# Out:
# (500000, 61)

# %%
#export combined samples as .csv files for data cleaning

samples_combined.to_csv(os.path.join(path, '02 Data', 'Original Data', 'Samples_Combined.csv'), index=False)  

# Specify index=False to avoid writing row numbers as a column

# %%
#begin data cleaning

samples_combined.info
# Out:
# <bound method DataFrame.info of          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 2079139  2018-12-02             Comair Inc.    DCA  BTV      False     False
# 4054924  2018-06-30        Spirit Air Lines    ATL  LAS      False     False
# 2486050  2018-02-11  Frontier Airlines Inc.    MCI  RSW      False     False
# 4020576  2018-06-22   United Air Lines Inc.    DEN  CID      False     False
# 715981   2018-10-19   SkyWest Airlines Inc.    BGM  DTW      False     False
# ...             ...                     ...    ...  ...        ...       ...
# 4016104  2022-03-08  Southwest Airlines Co.    DSM  DEN      False     False
# 3347015  2022-01-16       Republic Airlines    DCA  ATL      False     False
# 640944   2022-02-03  Southwest Airlines Co.    DEN  ORF      False     False
# 3329891  2022-01-09         JetBlue Airways    MCO  PSE      False     False
# 2702925  2022-06-22  Southwest Airlines Co.    DEN  SAT      False     False
#
# ...

# %%
#search for missing values

null_counts = samples_combined.isnull().sum()

# %%
null_counts
# Out:
# FlightDate                0
# Airline                   0
# Origin                    0
# Dest                      0
# Cancelled                 0
#                       ...
# ArrDel15              15443
# ArrivalDelayGroups    15443
# ArrTimeBlk                0
# DistanceGroup             0
# DivAirportLandings        3
# Length: 61, dtype: int64

# %%
#identify columns with mixed variable types

def detect_types(series):
    return series.apply(type).nunique()

mixed_type_columns = [col for col in samples_combined.columns if detect_types(samples_combined[col]) > 1]

print("Columns with mixed types:")
print(mixed_type_columns)
# Out:
# Columns with mixed types:
# ['Tail_Number']

# %% [markdown]
# ### The Tail_Number column is the only column with mixed data types. This is to be expected as most tail numbers contain a combination of letters and numbers. I will consider changing this column to an object or string data-type in the future.

# %%
#check counts

for column in samples_combined.columns:
    print(f"Counts for column {column}:")
    print(samples_combined[column].value_counts())
    print("\n")
# Out:
# Counts for column FlightDate:
# FlightDate
# 2022-07-01    553
# 2022-06-05    548
# 2022-06-08    547
# 2022-07-21    543
# 2022-04-28    539
#              ...
# 2020-05-12    107
# 2020-05-30    104
# 2020-05-17    103
# 2020-05-16    100
# 2020-05-19     87
# Name: count, Length: 1673, dtype: int64
#
#
# Counts for column Airline:
# Airline
# Southwest Airlines Co.                       94985
# Delta Air Lines Inc.                         56208
# SkyWest Airlines Inc.                        54538
# American Airlines Inc.                       53786
# United Air Lines Inc.                        40488
# Republic Airlines                            21969
# JetBlue Airways                              19131
# Envoy Air                                    18074
# Endeavor Air Inc.                            17155
# Comair Inc.                                  16247
# Alaska Airlines Inc.                         15220
# Spirit Air Lines                             14306
# ...

# %%
#remove duplicates and rename dataframe to more appropriate title

flights_clean = samples_combined.drop_duplicates()
print(flights_clean)
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 2079139  2018-12-02             Comair Inc.    DCA  BTV      False     False
# 4054924  2018-06-30        Spirit Air Lines    ATL  LAS      False     False
# 2486050  2018-02-11  Frontier Airlines Inc.    MCI  RSW      False     False
# 4020576  2018-06-22   United Air Lines Inc.    DEN  CID      False     False
# 715981   2018-10-19   SkyWest Airlines Inc.    BGM  DTW      False     False
# ...             ...                     ...    ...  ...        ...       ...
# 4016104  2022-03-08  Southwest Airlines Co.    DSM  DEN      False     False
# 3347015  2022-01-16       Republic Airlines    DCA  ATL      False     False
# 640944   2022-02-03  Southwest Airlines Co.    DEN  ORF      False     False
# 3329891  2022-01-09         JetBlue Airways    MCO  PSE      False     False
# 2702925  2022-06-22  Southwest Airlines Co.    DEN  SAT      False     False
#
# ...

# %% [markdown]
# ### No duplicates detected as evidenced by the shape remaining at 500000,61

# %%
#check column names

column_names = flights_clean.columns
print("Column Names:")
print(column_names)
# Out:
# Column Names:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %%
#export flights_clean as .csv file for future analysis

flights_clean.to_csv(os.path.join(path, '02 Data', 'Clean Data', 'Flights_Clean.csv'), index=False)  

# Specify index=False to avoid writing row numbers as a column
