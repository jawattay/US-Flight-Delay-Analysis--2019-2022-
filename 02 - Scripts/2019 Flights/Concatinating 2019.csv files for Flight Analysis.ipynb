# %%
import pandas as pd
import numpy as np
import os

# %%
# Set path

path = r'C:\Users\Josh Wattay\OneDrive\Documents\Desktop\Flight Delay Analysis - Raw Data\2019'

# %%
# Import Datasets

jan2019 = pd.read_csv(os.path.join(path, '1-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\3029557399.py:3: DtypeWarning: Columns (11,13,57,86,93,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2019 = pd.read_csv(os.path.join(path, '1-2019.csv'), index_col = False)

# %%
feb2019 = pd.read_csv(os.path.join(path, '2-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\1060989675.py:1: DtypeWarning: Columns (11,13,57,86,93,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   feb2019 = pd.read_csv(os.path.join(path, '2-2019.csv'), index_col = False)

# %%
mar2019 = pd.read_csv(os.path.join(path, '3-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\3165059037.py:1: DtypeWarning: Columns (11,13,57,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   mar2019 = pd.read_csv(os.path.join(path, '3-2019.csv'), index_col = False)

# %%
apr2019 = pd.read_csv(os.path.join(path, '4-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\1775534395.py:1: DtypeWarning: Columns (11,13,57,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   apr2019 = pd.read_csv(os.path.join(path, '4-2019.csv'), index_col = False)

# %%
may2019 = pd.read_csv(os.path.join(path, '5-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\921985669.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   may2019 = pd.read_csv(os.path.join(path, '5-2019.csv'), index_col = False)

# %%
jun2019 = pd.read_csv(os.path.join(path, '6-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\3396006896.py:1: DtypeWarning: Columns (11,13,57,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jun2019 = pd.read_csv(os.path.join(path, '6-2019.csv'), index_col = False)

# %%
jul2019 = pd.read_csv(os.path.join(path, '7-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\3300907035.py:1: DtypeWarning: Columns (11,13,57,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jul2019 = pd.read_csv(os.path.join(path, '7-2019.csv'), index_col = False)

# %%
aug2019 = pd.read_csv(os.path.join(path, '8-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\1988887576.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   aug2019 = pd.read_csv(os.path.join(path, '8-2019.csv'), index_col = False)

# %%
sep2019 = pd.read_csv(os.path.join(path, '9-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\4059631198.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   sep2019 = pd.read_csv(os.path.join(path, '9-2019.csv'), index_col = False)

# %%
oct2019 = pd.read_csv(os.path.join(path, '10-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\1847755736.py:1: DtypeWarning: Columns (11,13,57,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   oct2019 = pd.read_csv(os.path.join(path, '10-2019.csv'), index_col = False)

# %%
nov2019 = pd.read_csv(os.path.join(path, '11-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\2483459792.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   nov2019 = pd.read_csv(os.path.join(path, '11-2019.csv'), index_col = False)

# %%
dec2019 = pd.read_csv(os.path.join(path, '12-2019.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_15388\3452124633.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93,94,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   dec2019 = pd.read_csv(os.path.join(path, '12-2019.csv'), index_col = False)

# %%
frames = [jan2019, feb2019, mar2019, apr2019, may2019, jun2019, jul2019, aug2019, sep2019, oct2019, nov2019, dec2019]

# %%
frames
# Out:
# [        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
#  0       2019        1      1           4          5  2019-01-04
#  1       2019        1      1           4          5  2019-01-04
#  2       2019        1      1           4          5  2019-01-04
#  3       2019        1      1           4          5  2019-01-04
#  4       2019        1      1           4          5  2019-01-04
#  ...      ...      ...    ...         ...        ...         ...
#  638644  2019        1      1          23          3  2019-01-23
#  638645  2019        1      1          24          4  2019-01-24
#  638646  2019        1      1          25          5  2019-01-25
#  638647  2019        1      1          26          6  2019-01-26
#  638648  2019        1      1          28          1  2019-01-28
#
#         Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
#  0                             UA                            UA_CODESHARE
# ...

# %%
type(frames)
# Out:
# list

# %%
#Concatinate the Dataframes using Default Options

flights2019 = pd.concat(frames)

# %%
flights2019.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2019        1      1           4          5  2019-01-04
# 1  2019        1      1           4          5  2019-01-04
# 2  2019        1      1           4          5  2019-01-04
# 3  2019        1      1           4          5  2019-01-04
# 4  2019        1      1           4          5  2019-01-04
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                            UA_CODESHARE
# 1                        UA                            UA_CODESHARE
# 2                        UA                            UA_CODESHARE
# 3                        UA                            UA_CODESHARE
# 4                        UA                            UA_CODESHARE
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ...  Div5Airport  \
# 0                     19977                          UA  ...          NaN
# ...

# %%
flights2019.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        ...
#        'Div5Airport', 'Div5AirportID', 'Div5AirportSeqID', 'Div5WheelsOn',
#        'Div5TotalGTime', 'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum',
#        'Duplicate', 'Unnamed: 119'],
#       dtype='object', length=120)

# %%
flights2019 = flights2019.drop(columns=[
    'Operated_or_Branded_Code_Share_Partners', 
    'Originally_Scheduled_Code_Share_Airline', 
    'DOT_ID_Originally_Scheduled_Code_Share_Airline',
    'Flight_Num_Originally_Scheduled_Code_Share_Airline',
    'OriginWac', 'DestWac', 'DivAirportLandings', 'DivReachedDest',
    'DivActualElapsedTime', 'DivArrDelay', 
    'Div1Airport', 'Div1AirportID',
    'Div1AirportSeqID', 'Div1WheelsOn', 'Div1TotalGTime', 
    'Div1LongestGTime', 'Div1WheelsOff', 'Div1TailNum',
    'Div2Airport', 'Div2AirportID',
    'Div2AirportSeqID', 'Div2WheelsOn', 'Div2TotalGTime', 
    'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum',
    'Div3Airport', 'Div3AirportID',
    'Div3AirportSeqID', 'Div3WheelsOn', 'Div3TotalGTime', 
    'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum',
    'Div4Airport', 'Div4AirportID',
    'Div4AirportSeqID', 'Div4WheelsOn', 'Div4TotalGTime', 
    'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum',
    'Div5Airport', 'Div5AirportID',
    'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime', 
    'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum', 'Unnamed: 119'])

# %%
flights2019.shape
# Out:
# (8091684, 69)

# %%
flights2019.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2019        1      1           4          5  2019-01-04
# 1  2019        1      1           4          5  2019-01-04
# 2  2019        1      1           4          5  2019-01-04
# 3  2019        1      1           4          5  2019-01-04
# 4  2019        1      1           4          5  2019-01-04
#
#   Marketing_Airline_Network  DOT_ID_Marketing_Airline  \
# 0                        UA                     19977
# 1                        UA                     19977
# 2                        UA                     19977
# 3                        UA                     19977
# 4                        UA                     19977
#
#   IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  ...  \
# 0                          UA                             5657  ...
# 1                          UA                             5658  ...
# 2                          UA                             5658  ...
# ...

# %%
flights2019.to_csv(os.path.join(path, 'flights2019.csv'))
