# %%
import pandas as pd
import numpy as np
import os

# %%
# Set path

path = r'C:\Users\Josh Wattay\OneDrive\Documents\Desktop\Flight Delay Analysis - Raw Data\2020'

# %%
# Import Datasets

jan2020 = pd.read_csv(os.path.join(path, '1-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\3523904377.py:3: DtypeWarning: Columns (11,13,57,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2020 = pd.read_csv(os.path.join(path, '1-2020.csv'), index_col = False)

# %%
feb2020 = pd.read_csv(os.path.join(path, '2-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\4058752750.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   feb2020 = pd.read_csv(os.path.join(path, '2-2020.csv'), index_col = False)

# %%
mar2020 = pd.read_csv(os.path.join(path, '3-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\1290954184.py:1: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   mar2020 = pd.read_csv(os.path.join(path, '3-2020.csv'), index_col = False)

# %%
apr2020 = pd.read_csv(os.path.join(path, '4-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\2526720842.py:1: DtypeWarning: Columns (11,13,85,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   apr2020 = pd.read_csv(os.path.join(path, '4-2020.csv'), index_col = False)

# %%
may2020 = pd.read_csv(os.path.join(path, '5-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\1026981116.py:1: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   may2020 = pd.read_csv(os.path.join(path, '5-2020.csv'), index_col = False)

# %%
jun2020 = pd.read_csv(os.path.join(path, '6-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\915477729.py:1: DtypeWarning: Columns (11,13,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   jun2020 = pd.read_csv(os.path.join(path, '6-2020.csv'), index_col = False)

# %%
jul2020 = pd.read_csv(os.path.join(path, '7-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\2513858088.py:1: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   jul2020 = pd.read_csv(os.path.join(path, '7-2020.csv'), index_col = False)

# %%
aug2020 = pd.read_csv(os.path.join(path, '8-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\116939697.py:1: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   aug2020 = pd.read_csv(os.path.join(path, '8-2020.csv'), index_col = False)

# %%
sep2020 = pd.read_csv(os.path.join(path, '9-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\3074165942.py:1: DtypeWarning: Columns (11,13,57,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   sep2020 = pd.read_csv(os.path.join(path, '9-2020.csv'), index_col = False)

# %%
oct2020 = pd.read_csv(os.path.join(path, '10-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\4257207488.py:1: DtypeWarning: Columns (11,13,57,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   oct2020 = pd.read_csv(os.path.join(path, '10-2020.csv'), index_col = False)

# %%
nov2020 = pd.read_csv(os.path.join(path, '11-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\3041838301.py:1: DtypeWarning: Columns (11,13,57,78,85,86) have mixed types. Specify dtype option on import or set low_memory=False.
#   nov2020 = pd.read_csv(os.path.join(path, '11-2020.csv'), index_col = False)

# %%
dec2020 = pd.read_csv(os.path.join(path, '12-2020.csv'), index_col = False)
# Out:
# C:\Users\Josh Wattay\AppData\Local\Temp\ipykernel_3560\2096987464.py:1: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   dec2020 = pd.read_csv(os.path.join(path, '12-2020.csv'), index_col = False)

# %%
frames = [jan2020, feb2020, mar2020, apr2020, may2020, jun2020, jul2020, aug2020, sep2020, oct2020, nov2020, dec2020]

# %%
frames
# Out:
# [        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
#  0       2020        1      1          17          5  2020-01-17
#  1       2020        1      1          18          6  2020-01-18
#  2       2020        1      1          19          7  2020-01-19
#  3       2020        1      1          20          1  2020-01-20
#  4       2020        1      1          21          2  2020-01-21
#  ...      ...      ...    ...         ...        ...         ...
#  660551  2020        1      1           6          1  2020-01-06
#  660552  2020        1      1           6          1  2020-01-06
#  660553  2020        1      1           6          1  2020-01-06
#  660554  2020        1      1           6          1  2020-01-06
#  660555  2020        1      1           6          1  2020-01-06
#
#         Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
#  0                             B6                                      B6
# ...

# %%
type(frames)
# Out:
# list

# %%
#Concatinate the Dataframes using Default Options

flights2020 = pd.concat(frames)

# %%
flights2020.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2020        1      1          17          5  2020-01-17
# 1  2020        1      1          18          6  2020-01-18
# 2  2020        1      1          19          7  2020-01-19
# 3  2020        1      1          20          1  2020-01-20
# 4  2020        1      1          21          2  2020-01-21
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        B6                                      B6
# 1                        B6                                      B6
# 2                        B6                                      B6
# 3                        B6                                      B6
# 4                        B6                                      B6
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ...  Div5Airport  \
# 0                     20409                          B6  ...          NaN
# ...

# %%
flights2020.shape
# Out:
# (5022397, 120)

# %%
flights2020 = flights2020.drop(columns=[
    'Operated_or_Branded_Code_Share_Partners', 
    'Originally_Scheduled_Code_Share_Airline', 
    'DOT_ID_Originally_Scheduled_Code_Share_Airline',
    'Flight_Num_Originally_Scheduled_Code_Share_Airline',
    'OriginWac', 'DestWac', 'DivAirportLandings', 'DivReachedDest',
    'DivActualElapsedTime', 'DivArrDelay', 
    'Div1Airport', 'Div1AirportID',
    'Div1AirportSeqID', 'Div1WheelsOn', 'Div1TotalGTime', 
    'Div1LongestGTime', 'Div1WheelsOff', 'Div1TailNum',
    'Div2Airport', 'Div2AirportID',
    'Div2AirportSeqID', 'Div2WheelsOn', 'Div2TotalGTime', 
    'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum',
    'Div3Airport', 'Div3AirportID',
    'Div3AirportSeqID', 'Div3WheelsOn', 'Div3TotalGTime', 
    'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum',
    'Div4Airport', 'Div4AirportID',
    'Div4AirportSeqID', 'Div4WheelsOn', 'Div4TotalGTime', 
    'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum',
    'Div5Airport', 'Div5AirportID',
    'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime', 
    'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum', 'Unnamed: 119'])

# %%
flights2020.shape
# Out:
# (5022397, 69)

# %%
flights2020.to_csv(os.path.join(path, 'flights2020.csv'))
