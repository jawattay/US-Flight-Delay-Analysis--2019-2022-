# %% [markdown]
# # In This Notebook:
#
# ## 1. Overview of 2020 Flight Data
# ## 2. General Statistics
# ## 3. Temporal Analysis
# ## 4. Geospatial Analysis
# ## 5. Tail Number Analysis
# ## 6. Aggregation and Grouping (Wrangling)

# %%
#Import Libraries

import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Set Path

path = r'C:\Users\Josh Wattay\OneDrive\Documents\Desktop\Flight Delay Analysis'

# %%
# Import 2020 Flight Data Set

df = pd.read_csv(os.path.join(path, '01 - Data', 'flights2020.csv'), low_memory=False, index_col = 0)

# %% [markdown]
# ## 1. Overview of 2020 Flight Data

# %%
df.shape
# Out:
# (5022397, 66)

# %%
df.head()
# Out:
#    Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 0  2020        1      1            17            5  2020-01-17
# 1  2020        1      1            18            6  2020-01-18
# 2  2020        1      1            19            7  2020-01-19
# 3  2020        1      1            20            1  2020-01-20
# 4  2020        1      1            21            2  2020-01-21
#
#   Marketing_Airline_Network  DOT_ID_Marketing_Airline  \
# 0                        B6                     20409
# 1                        B6                     20409
# 2                        B6                     20409
# 3                        B6                     20409
# 4                        B6                     20409
#
#   IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  ... Distance  \
# 0                          B6                              942  ...   1133.0
# 1                          B6                              942  ...   1133.0
# 2                          B6                              942  ...   1133.0
# 3                          B6                              942  ...   1133.0
# 4                          B6                              942  ...   1133.0
#
#    Distance_Group Carrier_Delay Weather_Delay  NAS_Delay  Security_Delay  \
# 0               5           NaN           NaN        NaN             NaN
# 1               5           NaN           NaN        NaN             NaN
# 2               5           NaN           NaN        NaN             NaN
# 3               5           NaN           NaN        NaN             NaN
# 4               5           NaN           NaN        NaN             NaN
#
#    Late_Aircraft_Delay  Duplicate Missing_Due_To_Cancellation          Airline
# 0                  NaN          N                       False  JetBlue Airways
# 1                  NaN          N                       False  JetBlue Airways
# 2                  NaN          N                       False  JetBlue Airways
# 3                  NaN          N                       False  JetBlue Airways
# 4                  NaN          N                       False  JetBlue Airways
#
# [5 rows x 66 columns]

# %%
df.tail()
# Out:
#          Year  Quarter  Month  Day_of_Month  Day_of_Week Flight_Date  \
# 5022392  2020        4     12            30            3  2020-12-30
# 5022393  2020        4     12            30            3  2020-12-30
# 5022394  2020        4     12            30            3  2020-12-30
# 5022395  2020        4     12            30            3  2020-12-30
# 5022396  2020        4     12            30            3  2020-12-30
#
#         Marketing_Airline_Network  DOT_ID_Marketing_Airline  \
# 5022392                        UA                     19977
# 5022393                        UA                     19977
# 5022394                        UA                     19977
# 5022395                        UA                     19977
# 5022396                        UA                     19977
#
#         IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  ...  \
# 5022392                          UA                              277  ...
# 5022393                          UA                              276  ...
# 5022394                          UA                              275  ...
# 5022395                          UA                              274  ...
# 5022396                          UA                              273  ...
#
#         Distance  Distance_Group Carrier_Delay Weather_Delay  NAS_Delay  \
# 5022392    679.0               3           NaN           NaN        NaN
# 5022393    862.0               4          28.0           0.0        0.0
# 5022394   2454.0              10           NaN           NaN        NaN
# 5022395    305.0               2           0.0           0.0       15.0
# 5022396    937.0               4           NaN           NaN        NaN
#
#          Security_Delay  Late_Aircraft_Delay  Duplicate  \
# 5022392             NaN                  NaN          N
# 5022393             0.0                  0.0          N
# 5022394             NaN                  NaN          N
# 5022395             0.0                  0.0          N
# 5022396             NaN                  NaN          N
#
#         Missing_Due_To_Cancellation                Airline
# 5022392                       False  United Air Lines Inc.
# 5022393                       False  United Air Lines Inc.
# 5022394                       False  United Air Lines Inc.
# 5022395                       False  United Air Lines Inc.
# 5022396                       False  United Air Lines Inc.
#
# [5 rows x 66 columns]

# %%
# Display the column names to verify

print("DF DataFrame Columns:", df.columns)
# Out:
# DF DataFrame Columns: Index(['Year', 'Quarter', 'Month', 'Day_of_Month', 'Day_of_Week',
#        'Flight_Date', 'Marketing_Airline_Network', 'DOT_ID_Marketing_Airline',
#        'IATA_Code_Marketing_Airline', 'Flight_Number_Marketing_Airline',
#        'Operating_Airline', 'DOT_ID_Operating_Airline',
#        'IATA_Code_Operating_Airline', 'Tail_Number',
#        'Flight_Number_Operating_Airline', 'Origin_Airport_ID',
#        'Origin_Airport_Seq_ID', 'Origin_City_Market_ID', 'Origin',
#        'Origin_City_Name', 'Origin_State', 'Origin_State_Fips',
#        'Origin_State_Name', 'Dest_Airport_ID', 'Dest_Airport_Seq_ID',
#        'Dest_City_Market_ID', 'Dest', 'Dest_City_Name', 'Dest_State',
#        'Dest_State_Fips', 'Dest_State_Name', 'CRS_Dep_Time', 'Dep_Time',
#        'Dep_Delay', 'Dep_Delay_Minutes', 'Dep_Del_15',
#        'Departure_Delay_Groups', 'Dep_Time_Blk', 'Taxi_Out', 'Wheels_Off',
#        'Wheels_On', 'Taxi_In', 'CRS_Arr_Time', 'Arr_Time', 'Arr_Delay',
#        'Arr_Delay_Minutes', 'Arr_Del_15', 'Arrival_Delay_Groups',
#        'Arr_Time_Blk', 'Cancelled', 'Cancellation_Code', 'Diverted',
#        'CRS_Elapsed_Time', 'Actual_Elapsed_Time', 'Air_Time', 'Flights',
#        'Distance', 'Distance_Group', 'Carrier_Delay', 'Weather_Delay',
#        'NAS_Delay', 'Security_Delay', 'Late_Aircraft_Delay', 'Duplicate',
#        'Missing_Due_To_Cancellation', 'Airline'],
#       dtype='object')

# %% [markdown]
# ## 2. General Statistics

# %%
df.describe()
# Out:
#             Year       Quarter         Month  Day_of_Month   Day_of_Week  \
# count  5022397.0  5.022397e+06  5.022397e+06  5.022397e+06  5.022397e+06
# mean      2020.0  2.289412e+00  5.857175e+00  1.573752e+01  3.996955e+00
# std          0.0  1.207801e+00  3.715543e+00  8.811530e+00  2.003575e+00
# min       2020.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2020.0  1.000000e+00  2.000000e+00  8.000000e+00  2.000000e+00
# 50%       2020.0  2.000000e+00  6.000000e+00  1.600000e+01  4.000000e+00
# 75%       2020.0  3.000000e+00  9.000000e+00  2.300000e+01  6.000000e+00
# max       2020.0  4.000000e+00  1.200000e+01  3.100000e+01  7.000000e+00
#
#        DOT_ID_Marketing_Airline  Flight_Number_Marketing_Airline  \
# count              5.022397e+06                     5.022397e+06
# mean               1.981555e+04                     2.690128e+03
# std                2.694407e+02                     1.834531e+03
# min                1.939300e+04                     1.000000e+00
# 25%                1.979000e+04                     1.083000e+03
# 50%                1.980500e+04                     2.299000e+03
# 75%                1.997700e+04                     4.289000e+03
# max                2.043600e+04                     9.888000e+03
#
#        DOT_ID_Operating_Airline  Flight_Number_Operating_Airline  \
# count              5.022397e+06                     5.022397e+06
# mean               1.999914e+04                     2.690056e+03
# std                3.901717e+02                     1.834477e+03
# min                1.939300e+04                     1.000000e+00
# 25%                1.979000e+04                     1.083000e+03
# 50%                1.997700e+04                     2.299000e+03
# 75%                2.037800e+04                     4.289000e+03
# max                2.116700e+04                     9.888000e+03
#
#        Origin_Airport_ID  ...  Actual_Elapsed_Time      Air_Time    Flights  \
# count       5.022397e+06  ...         4.712930e+06  4.712930e+06  5022397.0
# mean        1.266246e+04  ...         1.283775e+02  1.061841e+02        1.0
# std         1.541555e+03  ...         6.713504e+01  6.592856e+01        0.0
# min         1.013500e+04  ...         1.300000e+01  7.000000e+00        1.0
# 25%         1.129200e+04  ...         8.000000e+01  5.800000e+01        1.0
# 50%         1.288900e+04  ...         1.120000e+02  8.900000e+01        1.0
# 75%         1.405700e+04  ...         1.580000e+02  1.360000e+02        1.0
# max         1.686900e+04  ...         7.630000e+02  6.980000e+02        1.0
#
#            Distance  Distance_Group  Carrier_Delay  Weather_Delay  \
# count  5.022397e+06    5.022397e+06  468954.000000  468954.000000
# mean   7.546099e+02    3.496368e+00      25.629173       4.338705
# std    5.504107e+02    2.180196e+00      74.677289      33.998934
# min    2.900000e+01    1.000000e+00       0.000000       0.000000
# 25%    3.500000e+02    2.000000e+00       0.000000       0.000000
# 50%    6.100000e+02    3.000000e+00       0.000000       0.000000
# 75%    9.920000e+02    4.000000e+00      24.000000       0.000000
# max    5.095000e+03    1.100000e+01    3864.000000    1706.000000
#
#            NAS_Delay  Security_Delay  Late_Aircraft_Delay
# count  468954.000000   468954.000000        468954.000000
# mean       13.540560        0.137295            18.899180
# std        30.800488        3.391041            51.190193
# min         0.000000        0.000000             0.000000
# 25%         0.000000        0.000000             0.000000
# 50%         2.000000        0.000000             0.000000
# 75%        19.000000        0.000000            18.000000
# max      1462.000000     1185.000000          2361.000000
#
# [8 rows x 46 columns]

# %%
# Calculate general statistics for delays and cancellations
delay_stats = df[['Dep_Delay', 'Arr_Delay', 'Cancelled', 'Diverted']].describe()
print(delay_stats)
# Out:
#           Dep_Delay     Arr_Delay     Cancelled      Diverted
# count  4.722714e+06  4.712930e+06  5.022397e+06  5.022397e+06
# mean   2.064780e+00 -4.863644e+00  5.994249e-02  1.674698e-03
# std    3.639112e+01  3.842280e+01  2.373803e-01  4.088880e-02
# min   -1.310000e+02 -1.390000e+02  0.000000e+00  0.000000e+00
# 25%   -7.000000e+00 -1.900000e+01  0.000000e+00  0.000000e+00
# 50%   -4.000000e+00 -1.100000e+01  0.000000e+00  0.000000e+00
# 75%   -1.000000e+00 -1.000000e+00  0.000000e+00  0.000000e+00
# max    3.890000e+03  3.864000e+03  1.000000e+00  1.000000e+00

# %%
# Identify the most common delay reasons and cancellation codes
common_delays = df[['Carrier_Delay', 'Weather_Delay', 'NAS_Delay', 'Security_Delay', 'Late_Aircraft_Delay']].sum()
print(common_delays)
# Out:
# Carrier_Delay          12018903.0
# Weather_Delay           2034653.0
# NAS_Delay               6349900.0
# Security_Delay            64385.0
# Late_Aircraft_Delay     8862846.0
# dtype: float64

# %%
common_cancellation_codes = df['Cancellation_Code'].value_counts()
print(common_cancellation_codes)
# Out:
# Cancellation_Code
# D    250248
# B     23463
# A     22487
# C      4857
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Temporal Analysis

# %%
# Analyze delays and cancellations by day of the week

delays_by_day = df.groupby('Day_of_Week')[['Dep_Delay', 'Arr_Delay']].mean()
print(delays_by_day)
# Out:
#              Dep_Delay  Arr_Delay
# Day_of_Week
# 1             1.625902  -5.263461
# 2             0.797999  -6.603266
# 3             1.138613  -5.924002
# 4             3.410131  -2.824469
# 5             3.203345  -3.255633
# 6             1.940102  -5.499929
# 7             2.118043  -5.024112

# %%
cancellations_by_day = df.groupby('Day_of_Week')['Cancelled'].sum()
print(cancellations_by_day)
# Out:
# Day_of_Week
# 1    44810.0
# 2    42481.0
# 3    41731.0
# 4    46107.0
# 5    46754.0
# 6    37752.0
# 7    41420.0
# Name: Cancelled, dtype: float64

# %%
# Analyze delays and cancellations by month
delays_by_month = df.groupby('Month')[['Dep_Delay', 'Arr_Delay']].mean()
print(delays_by_month)
# Out:
#        Dep_Delay  Arr_Delay
# Month
# 1       6.355502  -1.195899
# 2       7.579590   0.180622
# 3       1.407063  -6.305819
# 4      -3.337845 -13.850635
# 5      -2.033445 -11.575293
# 6      -0.346177  -7.307155
# 7       0.593170  -4.902876
# 8      -0.131137  -6.045285
# 9      -0.630611  -7.478879
# 10      0.784558  -4.978135
# 11     -0.371310  -6.507540
# 12      2.804599  -2.507018

# %%
cancellations_by_month = df.groupby('Month')['Cancelled'].sum()
print(cancellations_by_month)
# Out:
# Month
# 1       8416.0
# 2       6095.0
# 3     118276.0
# 4     136848.0
# 5      12261.0
# 6       1030.0
# 7       2926.0
# 8       4327.0
# 9       2523.0
# 10      1994.0
# 11      2106.0
# 12      4253.0
# Name: Cancelled, dtype: float64

# %%
# Analyze delays and cancellations by quarter

delays_by_quarter = df.groupby('Quarter')[['Dep_Delay', 'Arr_Delay']].mean()
print(delays_by_quarter)
# Out:
#          Dep_Delay  Arr_Delay
# Quarter
# 1         5.205639  -2.346324
# 2        -1.796183 -10.648465
# 3        -0.044897  -6.110000
# 4         1.085535  -4.648872

# %%
cancellations_by_quarter = df.groupby('Quarter')['Cancelled'].sum()
print(cancellations_by_quarter)
# Out:
# Quarter
# 1    132787.0
# 2    150139.0
# 3      9776.0
# 4      8353.0
# Name: Cancelled, dtype: float64

# %% [markdown]
# ## 4. Geospatial Analysis

# %%
# Determine the origin and destination airports with the highest delays and cancellations

origin_delays = df.groupby('Origin_City_Name')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Dep_Delay', ascending=False)
print(origin_delays.head(10))
# Out:
#                      Dep_Delay  Arr_Delay
# Origin_City_Name
# Pago Pago, TT        80.043478  73.913043
# Cold Bay, AK         31.733333  36.798319
# Alamosa, CO          31.520000   8.850000
# Mammoth Lakes, CA    23.597990   9.326633
# Alpena, MI           16.657581   6.379074
# Pellston, MI         16.497561   8.514042
# Binghamton, NY       16.272512   5.584323
# Eagle, CO            16.255987   8.639698
# Aspen, CO            16.018178  10.445690
# Riverton/Lander, WY  15.614699  11.715247

# %%
destination_delays = df.groupby('Dest_City_Name')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Arr_Delay', ascending=False)
print(destination_delays.head(10))
# Out:
#                           Dep_Delay  Arr_Delay
# Dest_City_Name
# Pago Pago, TT             76.391304  76.565217
# Adak Island, AK           10.322917  16.159574
# Cold Bay, AK               7.390625  15.277311
# Aspen, CO                 17.184371  11.725367
# Hobbs, NM                 13.800000  11.408971
# Mammoth Lakes, CA         19.396135   9.030000
# Presque Isle/Houlton, ME  11.903226   7.922693
# Punta Gorda, FL            7.057126   6.503428
# Laramie, WY                7.865248   6.234767
# Sanford, FL                7.567596   5.509183

# %%
# Identify the airlines with the highest delays and cancellations
airline_delays = df.groupby('Airline')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Dep_Delay', ascending=False)
print(airline_delays)
# Out:
#                                            Dep_Delay  Arr_Delay
# Airline
# Trans States Airlines                       7.649544   2.898856
# Commutair Aka Champlain Enterprises, Inc.   6.838677   3.029948
# Allegiant Air                               5.907016   3.382668
# Comair Inc.                                 4.843367   0.532815
# Mesa Airlines Inc.                          4.770252  -0.110854
# Spirit Air Lines                            3.863564  -3.153026
# SkyWest Airlines Inc.                       3.782448  -3.769550
# American Airlines Inc.                      3.062314  -4.182455
# Compass Airlines                            2.698325  -3.024691
# GoJet Airlines, LLC d/b/a United Express    2.102838  -6.528052
# United Air Lines Inc.                       1.960415  -6.973678
# Envoy Air                                   1.696600  -1.142255
# Delta Air Lines Inc.                        1.588046  -3.835111
# JetBlue Airways                             1.467052  -5.257761
# Capital Cargo International                 1.464145  -3.314068
# Air Wisconsin Airlines Corp                 1.081872  -5.674131
# Southwest Airlines Co.                      1.021615  -8.498458
# Frontier Airlines Inc.                      0.904193  -6.396977
# Endeavor Air Inc.                           0.795534  -7.032632
# Empire Airlines Inc.                        0.619188  -0.670193
# Horizon Air                                 0.435140  -3.633259
# ExpressJet Airlines Inc.                    0.005872  -4.816521
# Republic Airlines                          -0.540447  -8.368260
# Alaska Airlines Inc.                       -1.181085  -6.489409
# Hawaiian Airlines Inc.                     -1.214776  -3.309237

# %%
airline_cancellations = df.groupby('Airline')['Cancelled'].sum().sort_values(ascending=False)
print(airline_cancellations)
# Out:
# Airline
# Southwest Airlines Co.                       77842.0
# American Airlines Inc.                       34262.0
# Delta Air Lines Inc.                         28769.0
# SkyWest Airlines Inc.                        24881.0
# United Air Lines Inc.                        22593.0
# Allegiant Air                                14296.0
# Comair Inc.                                  14099.0
# Envoy Air                                    11194.0
# Republic Airlines                            10516.0
# JetBlue Airways                               7982.0
# Mesa Airlines Inc.                            7974.0
# Endeavor Air Inc.                             6940.0
# Capital Cargo International                   5505.0
# Alaska Airlines Inc.                          5481.0
# Frontier Airlines Inc.                        4691.0
# Horizon Air                                   4370.0
# ExpressJet Airlines Inc.                      4022.0
# Air Wisconsin Airlines Corp                   3532.0
# Spirit Air Lines                              2964.0
# GoJet Airlines, LLC d/b/a United Express      2321.0
# Hawaiian Airlines Inc.                        2144.0
# Trans States Airlines                         1618.0
# Commutair Aka Champlain Enterprises, Inc.     1523.0
# Compass Airlines                              1193.0
# Empire Airlines Inc.                           343.0
# Name: Cancelled, dtype: float64

# %% [markdown]
# ## 5. Tail Number Analysis

# %%
# Check if specific aircraft tail numbers are more prone to delays or cancellations
tail_number_delays = df.groupby('Tail_Number')[['Dep_Delay', 'Arr_Delay']].mean().sort_values(by='Dep_Delay', ascending=False)
print(tail_number_delays.head(10))
# Out:
#               Dep_Delay   Arr_Delay
# Tail_Number
# N863DA       213.500000  201.000000
# N404DX       124.666667  125.666667
# N717AN        95.838710   88.967742
# N686UA        88.250000   76.250000
# N669UA        79.333333   88.666667
# N668UA        62.777778   53.222222
# N2333U        58.238095   47.857143
# N166GJ        50.952381   41.476190
# N731AN        48.650000   41.450000
# N801AC        45.870130   34.181818

# %%
tail_number_cancellations = df.groupby('Tail_Number')['Cancelled'].sum().sort_values(ascending=False)
print(tail_number_cancellations.head(10))
# Out:
# Tail_Number
# Unknown    168451.0
# N201JQ        202.0
# N743SK        128.0
# N443QX        126.0
# N706SK        118.0
# N766SK        108.0
# N752SK        106.0
# N748SK        104.0
# N427QX        104.0
# N793SK        102.0
# Name: Cancelled, dtype: float64

# %% [markdown]
# ## 6. Aggregation and Grouping (Wrangling)

# %%
# Group by various metrics to gain insights
grouped_by_airline = df.groupby('Airline').agg({
    'Dep_Delay': 'mean',
    'Arr_Delay': 'mean',
    'Cancelled': 'sum'
}).sort_values(by='Dep_Delay', ascending=False)
print(grouped_by_airline)
# Out:
#                                            Dep_Delay  Arr_Delay  Cancelled
# Airline
# Trans States Airlines                       7.649544   2.898856     1618.0
# Commutair Aka Champlain Enterprises, Inc.   6.838677   3.029948     1523.0
# Allegiant Air                               5.907016   3.382668    14296.0
# Comair Inc.                                 4.843367   0.532815    14099.0
# Mesa Airlines Inc.                          4.770252  -0.110854     7974.0
# Spirit Air Lines                            3.863564  -3.153026     2964.0
# SkyWest Airlines Inc.                       3.782448  -3.769550    24881.0
# American Airlines Inc.                      3.062314  -4.182455    34262.0
# Compass Airlines                            2.698325  -3.024691     1193.0
# GoJet Airlines, LLC d/b/a United Express    2.102838  -6.528052     2321.0
# United Air Lines Inc.                       1.960415  -6.973678    22593.0
# Envoy Air                                   1.696600  -1.142255    11194.0
# Delta Air Lines Inc.                        1.588046  -3.835111    28769.0
# JetBlue Airways                             1.467052  -5.257761     7982.0
# Capital Cargo International                 1.464145  -3.314068     5505.0
# Air Wisconsin Airlines Corp                 1.081872  -5.674131     3532.0
# Southwest Airlines Co.                      1.021615  -8.498458    77842.0
# Frontier Airlines Inc.                      0.904193  -6.396977     4691.0
# Endeavor Air Inc.                           0.795534  -7.032632     6940.0
# Empire Airlines Inc.                        0.619188  -0.670193      343.0
# Horizon Air                                 0.435140  -3.633259     4370.0
# ExpressJet Airlines Inc.                    0.005872  -4.816521     4022.0
# Republic Airlines                          -0.540447  -8.368260    10516.0
# Alaska Airlines Inc.                       -1.181085  -6.489409     5481.0
# Hawaiian Airlines Inc.                     -1.214776  -3.309237     2144.0

# %%
grouped_by_airport = df.groupby('Origin_City_Name').agg({
    'Dep_Delay': 'mean',
    'Arr_Delay': 'mean',
    'Cancelled': 'sum'
}).sort_values(by='Dep_Delay', ascending=False)
print(grouped_by_airport)
# Out:
#                    Dep_Delay  Arr_Delay  Cancelled
# Origin_City_Name
# Pago Pago, TT      80.043478  73.913043        3.0
# Cold Bay, AK       31.733333  36.798319       13.0
# Alamosa, CO        31.520000   8.850000        4.0
# Mammoth Lakes, CA  23.597990   9.326633       71.0
# Alpena, MI         16.657581   6.379074        7.0
# ...                      ...        ...        ...
# Gustavus, AK       -8.855263  -3.868421        6.0
# Deadhorse, AK      -8.914530  -5.003448       26.0
# Yakutat, AK        -9.267054  -7.269795       37.0
# Saipan, TT         -9.411504 -10.685841        5.0
# Hyannis, MA       -11.722222 -21.444444        4.0
#
# [373 rows x 3 columns]

# %%
# Import Seaborn for Visualizations

import seaborn as sns

# %%
# Ensure that Flight Date is in datetime format

df['Flight_Date'] = pd.to_datetime(df['Flight_Date'])
df_2020 = df[df['Flight_Date'].dt.year == 2020]

# %%
# Set save path for saving visuals

save_path = os.path.join(path, '03 - Visuals')

# %%
# Delays by Day of the Week
delays_by_day = df_2020.groupby('Day_of_Week')[['Dep_Delay', 'Arr_Delay']].mean()
delays_by_day.plot(kind='bar', figsize=(10, 6), title='2020 Average Delays by Day of the Week')
plt.ylabel('Average Delay (minutes)')
plt.savefig(f'{save_path}delays_by_day_of_week_2020.png')
plt.show()

# %%
delays_by_quarter = df_2020.groupby('Quarter')[['Dep_Delay', 'Arr_Delay']].mean()

# %%
# Plot the delays by quarter
delays_by_quarter.plot(kind='bar', figsize=(10, 6), title='2020 Average Delays by Quarter')
plt.ylabel('Average Delay (minutes)')
plt.xlabel('Quarter')
plt.tight_layout()  # Adjust layout to prevent clipping
plt.savefig(f'{save_path}delays_by_quarter_2020.png')
plt.show()

# %%
# Cancellations by Day of the Week
cancellations_by_day = df_2020.groupby('Day_of_Week')['Cancelled'].sum()
ax = cancellations_by_day.plot(kind='bar', figsize=(10, 6), title='2020 Cancellations by Day of the Week', color='red')
plt.ylabel('Number of Cancellations')
plt.savefig(f'{save_path}cancellations_by_day_of_week_2020.png')
plt.show()

# %%
# Monthly Trends
delays_by_month = df_2020.groupby('Month')[['Dep_Delay', 'Arr_Delay']].mean()
ax = delays_by_month.plot(kind='line', figsize=(10, 6), title='2020 Average Delays by Month')
plt.ylabel('Average Delay (minutes)')
plt.savefig(f'{save_path}delays_by_month_2020.png')
plt.show()

# %%
# Monthly Cancellation Trends
cancellations_by_month = df_2020.groupby('Month')[['Cancelled']].sum()
ax = cancellations_by_month.plot(kind='line', figsize=(10, 6), title='2020 Cancellations by Month')
plt.ylabel('Number of Cancellations')
plt.savefig(f'{save_path}cancellations_by_month_2020.png')
plt.show()

# %%
# Heatmap for Origin-Destination Analysis
origin_dest_delays = df_2020.pivot_table(index='Origin', columns='Dest', values='Dep_Delay', aggfunc='mean')
plt.figure(figsize=(12, 8))
sns.heatmap(origin_dest_delays, cmap='coolwarm', annot=False, vmin=0, vmax=200) #set scale for 0-200
plt.title('2020 Average Departure Delays for Origin-Destination Pairs')
plt.savefig(f'{save_path}origin_dest_delays_heatmap_2020.png')
plt.show()

# %%
# Dictionary mapping abbreviations to full names
airline_mapping = {
    'AA': 'American Airlines Inc.',
    'AS': 'Alaska Airlines Inc.',
    'B6': 'JetBlue Airways',
    'DL': 'Delta Air Lines Inc.',
    'F9': 'Frontier Airlines Inc.',
    'G4': 'Allegiant Air',
    'HA': 'Hawaiian Airlines Inc.',
    'NK': 'Spirit Air Lines',
    'UA': 'United Airlines Inc.',
    'VX': 'Virgin America',
    'WN': 'Southwest Airlines Co.'
}

# %%
# Add a new column with full names
df_2020['Marketing_Airline_Network_Full'] = df_2020['Marketing_Airline_Network'].map(airline_mapping)

# %%
# Rename columns
df_2020 = df_2020.rename(columns={
    'Marketing_Airline_Network': 'Marketing_Airline_Network_Code',
    'Marketing_Airline_Network_Full': 'Marketing_Airline_Network'
})

# %%
# Distribution of Delays by Marketing Airline Network
plt.figure(figsize=(16, 10))  # Increase the width and height of the figure
sns.boxplot(x='Marketing_Airline_Network', y='Dep_Delay', data=df_2020)
plt.title('2020 Distribution of Departure Delays by Marketing Airline Network', fontsize=16)
plt.ylabel('Departure Delay (minutes)', fontsize=14)
plt.xlabel('Marketing Airline Network', fontsize=14)
plt.xticks(rotation=45, fontsize=10)  # Rotate labels and adjust font size
plt.tight_layout()  # Adjust layout to prevent clipping
plt.savefig(f'{save_path}delays_by_airline_network_boxplot_2020.png')
plt.show()

# %% [markdown]
# ## I will be using Tableau for further Geospatial Analsysis.

# %%
# Count the number of flights per month using the existing 'Month' column
flights_per_month = df_2020['Month'].value_counts().sort_index()

# %%
# Plot the line chart

ax = flights_per_month.plot(kind='line', figsize=(10, 6), title='2020 Flights per Month')
plt.ylabel('Number of Flights')
plt.savefig(f'{save_path}flights_per_month_2020.png')
plt.show()

# %%
# Save 2020 flights dataframe, now with Marketing_Airline_Network & Marketing_Airline_Network_Code columns

df_2020.to_csv(os.path.join(path, 'flights2020.csv'))
